# %%
load_dotenv()
openai_api_key = os.getenv("OPENAI_API_KEY")

# %%
import pandas as pd
from qdrant_client import QdrantClient
from qdrant_client.models import Distance, VectorParams, PointStruct
from sentence_transformers import SentenceTransformer
from bs4 import BeautifulSoup
import uuid
import os
from openai import OpenAI
from dotenv import load_dotenv
load_dotenv()

# ✅ Assign the API key
openai_api_key = os.getenv("OPENAI_API_KEY")

# ✅ Use it here
openai_client = OpenAI(
    api_key=openai_api_key
)

# %%
from qdrant_client import QdrantClient
from qdrant_client.models import VectorParams, Distance, PayloadSchemaType

# 1. Connect to Qdrant
client = QdrantClient(host="vps.maestri.com.co", port=6333, https=False)

# 2. Collection name and vector size
collection_name = "user_history"
embedding_size = 1536  # If you're using OpenAI's text-embedding-3-small

# 3. Check if the collection exists and delete it (optional)
if client.collection_exists(collection_name):
    print(f"🗑️ Deleting existing collection '{collection_name}'...")
    client.delete_collection(collection_name)

# 4. Create collection
print(f"🛠️ Creating collection '{collection_name}'...")
client.create_collection(
    collection_name=collection_name,
    vectors_config=VectorParams(size=embedding_size, distance=Distance.COSINE),
    on_disk_payload=True
)
print(f"✅ Collection '{collection_name}' created.")

# 5. Define and create payload indexes (metadata fields)
fields = {
    "question": PayloadSchemaType.TEXT,
    "answer": PayloadSchemaType.TEXT,
    "subscriber_id": PayloadSchemaType.KEYWORD,
    "product_ids": PayloadSchemaType.KEYWORD,  # list of product slugs or IDs
    "timestamp": PayloadSchemaType.TEXT
}

print("🔧 Creating payload indexes...")
for field_name, field_type in fields.items():
    client.create_payload_index(
        collection_name=collection_name,
        field_name=field_name,
        field_schema=field_type
    )
print("✅ All payload indexes created successfully.")
# Out:
# 🛠️ Creating collection 'user_history'...
# ✅ Collection 'user_history' created.
# 🔧 Creating payload indexes...
# ✅ All payload indexes created successfully.

# %%
from qdrant_client import QdrantClient
from qdrant_client.http.models import PointStruct, VectorParams, Distance
from bs4 import BeautifulSoup
import pandas as pd
import uuid
from openai import OpenAI # ✅ add openai import


# Utility functions
def clean(text):
    if pd.isna(text): return ""
    return str(text).strip()

def strip_html(text):
    return BeautifulSoup(text, "html.parser").get_text(separator=" ", strip=True)


def get_openai_embedding(text: str) -> list:
    response = openai_client.embeddings.create(
        model="text-embedding-3-small",
        input=text
    )
    return response.data[0].embedding

# Load CSV
df = pd.read_csv("/Users/diegohernandez/Downloads/Maestri Milano - Products.csv")
df.columns = [col.strip().lower().replace(" ", "_") for col in df.columns]

# Connect to Qdrant
client = QdrantClient(host="vps.maestri.com.co", port=6333, https=False)
collection_name = "maestri_products"
embedding_size = 1536  # ✅ OpenAI embedding size is 1536

client.recreate_collection(
    collection_name=collection_name,
    vectors_config=VectorParams(size=embedding_size, distance=Distance.COSINE),
)

points = []

for _, row in df.iterrows():
    if pd.isna(row.get("published_on")):
        continue

    product_name = clean(row.get("nombre"))
    bodega = clean(row.get("bodega"))
    region = clean(row.get("región"))
    tipo = clean(row.get("tipo"))
    maridaje1 = clean(row.get("maridaje_1"))
    maridaje2 = clean(row.get("maridaje_2"))
    maridaje = " y ".join([m for m in [maridaje1, maridaje2] if m])
    notas = clean(row.get("notas_de_cata"))
    descripcion = strip_html(clean(row.get("descripción")))
    precio = clean(row.get("precio"))
    category = clean(row.get("pasillo"))
    alternate_names = ""  

    short_text = f"""\
                Producto: {product_name}. Tipo: {tipo}. Bodega: {bodega}. Región: {region}.
                Maridaje: {maridaje}. Notas: {notas}. Descripción: {descripcion}.
                También conocido como: {alternate_names}. Precio: {precio}.
                """

    if not short_text.strip():
        continue

    # ✅ Now using OpenAI to generate the embedding
    vector = get_openai_embedding(short_text)

    payload = {
        "product_name": product_name,
        "bodega": bodega,
        "region": region,
        "tipo": tipo,
        "precio": precio,
        "notas": notas,
        "descripcion": descripcion,
        "maridaje": maridaje,
        "category": category,
        "alternate_names": alternate_names
    }

    points.append(PointStruct(id=str(uuid.uuid4()), vector=vector, payload=payload))

# Insert into Qdrant
client.upsert(collection_name=collection_name, points=points)
print(f"✅ Inserted {len(points)} products into Qdrant collection: {collection_name}")
# Out:
# /var/folders/xq/gclpc2_d3ql92h6tddvfwkjr0000gn/T/ipykernel_30796/3315711371.py:34: DeprecationWarning: `recreate_collection` method is deprecated and will be removed in the future. Use `collection_exists` to check collection existence and `create_collection` instead.
#   client.recreate_collection(
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File ~/Library/Python/3.9/lib/python/site-packages/httpx/_transports/default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File ~/Library/Python/3.9/lib/python/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File ~/Library/Python/3.9/lib/python/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#
# File ~/Library/Python/3.9/lib/python/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#
# File ~/Library/Python/3.9/lib/python/site-packages/httpcore/_sync/connection.py:101, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
# --> 101     raise exc
#     103 return self._connection.handle_request(request)
#
# File ~/Library/Python/3.9/lib/python/site-packages/httpcore/_sync/connection.py:78, in HTTPConnection.handle_request(self, request)
#      77 if self._connection is None:
# ---> 78     stream = self._connect(request)
#      80     ssl_object = stream.get_extra_info("ssl_object")
#
# File ~/Library/Python/3.9/lib/python/site-packages/httpcore/_sync/connection.py:124, in HTTPConnection._connect(self, request)
#     123 with Trace("connect_tcp", logger, request, kwargs) as trace:
# --> 124     stream = self._network_backend.connect_tcp(**kwargs)
#     125     trace.return_value = stream
#
# File ~/Library/Python/3.9/lib/python/site-packages/httpcore/_backends/sync.py:215, in SyncBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#     214         sock.setsockopt(*option)  # pragma: no cover
# --> 215     sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#     216 return SyncStream(sock)
#
# File /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/contextlib.py:135, in _GeneratorContextManager.__exit__(self, type, value, traceback)
#     134 try:
# --> 135     self.gen.throw(type, value, traceback)
#     136 except StopIteration as exc:
#     137     # Suppress StopIteration *unless* it's the same exception that
#     138     # was passed to throw().  This prevents a StopIteration
#     139     # raised inside the "with" statement from being suppressed.
#
# File ~/Library/Python/3.9/lib/python/site-packages/httpcore/_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ConnectError: [Errno 8] nodename nor servname provided, or not known
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# File ~/Library/Python/3.9/lib/python/site-packages/qdrant_client/http/api_client.py:116, in ApiClient.send_inner(self, request)
#     115 try:
# --> 116     response = self._client.send(request)
#     117 except Exception as e:
#
# File ~/Library/Python/3.9/lib/python/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#
# File ~/Library/Python/3.9/lib/python/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#
# File ~/Library/Python/3.9/lib/python/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#
# File ~/Library/Python/3.9/lib/python/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#
# File ~/Library/Python/3.9/lib/python/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/contextlib.py:135, in _GeneratorContextManager.__exit__(self, type, value, traceback)
#     134 try:
# --> 135     self.gen.throw(type, value, traceback)
#     136 except StopIteration as exc:
#     137     # Suppress StopIteration *unless* it's the same exception that
#     138     # was passed to throw().  This prevents a StopIteration
#     139     # raised inside the "with" statement from being suppressed.
#
# File ~/Library/Python/3.9/lib/python/site-packages/httpx/_transports/default.py:118, in map_httpcore_exceptions()
#     117 message = str(exc)
# --> 118 raise mapped_exc(message) from exc
#
# ConnectError: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# ResponseHandlingException                 Traceback (most recent call last)
# Cell In[13], line 34
#      31 collection_name = "maestri_products"
#      32 embedding_size = 1536  # ✅ OpenAI embedding size is 1536
# ---> 34 client.recreate_collection(
#      35     collection_name=collection_name,
#      36     vectors_config=VectorParams(size=embedding_size, distance=Distance.COSINE),
#      37 )
#      39 points = []
#      41 for _, row in df.iterrows():
#
# File ~/Library/Python/3.9/lib/python/site-packages/qdrant_client/qdrant_client.py:2407, in QdrantClient.recreate_collection(self, collection_name, vectors_config, sparse_vectors_config, shard_number, sharding_method, replication_factor, write_consistency_factor, on_disk_payload, hnsw_config, optimizers_config, wal_config, quantization_config, init_from, timeout, strict_mode_config, **kwargs)
#    2398 assert len(kwargs) == 0, f"Unknown arguments: {list(kwargs.keys())}"
#    2400 warnings.warn(
#    2401     "`recreate_collection` method is deprecated and will be removed in the future."
#    2402     " Use `collection_exists` to check collection existence and `create_collection` instead.",
#    2403     DeprecationWarning,
#    2404     stacklevel=2,
#    2405 )
# -> 2407 return self._client.recreate_collection(
#    2408     collection_name=collection_name,
#    2409     vectors_config=vectors_config,
#    2410     shard_number=shard_number,
#    2411     sharding_method=sharding_method,
#    2412     replication_factor=replication_factor,
#    2413     write_consistency_factor=write_consistency_factor,
#    2414     on_disk_payload=on_disk_payload,
#    2415     hnsw_config=hnsw_config,
#    2416     optimizers_config=optimizers_config,
#    2417     wal_config=wal_config,
#    2418     quantization_config=quantization_config,
#    2419     init_from=init_from,
#    2420     timeout=timeout,
#    2421     sparse_vectors_config=sparse_vectors_config,
#    2422     strict_mode_config=strict_mode_config,
#    2423     **kwargs,
#    2424 )
#
# File ~/Library/Python/3.9/lib/python/site-packages/qdrant_client/qdrant_remote.py:2838, in QdrantRemote.recreate_collection(self, collection_name, vectors_config, shard_number, replication_factor, write_consistency_factor, on_disk_payload, hnsw_config, optimizers_config, wal_config, quantization_config, init_from, timeout, sparse_vectors_config, sharding_method, strict_mode_config, **kwargs)
#    2819 def recreate_collection(
#    2820     self,
#    2821     collection_name: str,
#    (...)
#    2836     **kwargs: Any,
#    2837 ) -> bool:
# -> 2838     self.delete_collection(collection_name, timeout=timeout)
#    2840     return self.create_collection(
#    2841         collection_name=collection_name,
#    2842         vectors_config=vectors_config,
#    (...)
#    2855         strict_mode_config=strict_mode_config,
#    2856     )
#
# File ~/Library/Python/3.9/lib/python/site-packages/qdrant_client/qdrant_remote.py:2694, in QdrantRemote.delete_collection(self, collection_name, timeout, **kwargs)
#    2688 if self._prefer_grpc:
#    2689     return self.grpc_collections.Delete(
#    2690         grpc.DeleteCollection(collection_name=collection_name, timeout=timeout),
#    2691         timeout=timeout if timeout is not None else self._timeout,
#    2692     ).result
# -> 2694 result: Optional[bool] = self.http.collections_api.delete_collection(
#    2695     collection_name, timeout=timeout
#    2696 ).result
#    2697 assert result is not None, "Delete collection returned None"
#    2698 return result
#
# File ~/Library/Python/3.9/lib/python/site-packages/qdrant_client/http/api/collections_api.py:308, in SyncCollectionsApi.delete_collection(self, collection_name, timeout)
#     300 def delete_collection(
#     301     self,
#     302     collection_name: str,
#     303     timeout: int = None,
#     304 ) -> m.InlineResponse200:
#     305     """
#     306     Drop collection and all associated data
#     307     """
# --> 308     return self._build_for_delete_collection(
#     309         collection_name=collection_name,
#     310         timeout=timeout,
#     311     )
#
# File ~/Library/Python/3.9/lib/python/site-packages/qdrant_client/http/api/collections_api.py:123, in _CollectionsApi._build_for_delete_collection(self, collection_name, timeout)
#     120     query_params["timeout"] = str(timeout)
#     122 headers = {}
# --> 123 return self.api_client.request(
#     124     type_=m.InlineResponse200,
#     125     method="DELETE",
#     126     url="/collections/{collection_name}",
#     127     headers=headers if headers else None,
#     128     path_params=path_params,
#     129     params=query_params,
#     130 )
#
# File ~/Library/Python/3.9/lib/python/site-packages/qdrant_client/http/api_client.py:89, in ApiClient.request(self, type_, method, url, path_params, **kwargs)
#      87     kwargs["timeout"] = int(kwargs["params"]["timeout"])
#      88 request = self._client.build_request(method, url, **kwargs)
# ---> 89 return self.send(request, type_)
#
# File ~/Library/Python/3.9/lib/python/site-packages/qdrant_client/http/api_client.py:106, in ApiClient.send(self, request, type_)
#     105 def send(self, request: Request, type_: Type[T]) -> T:
# --> 106     response = self.middleware(request, self.send_inner)
#     107     if response.status_code in [200, 201, 202]:
#     108         try:
#
# File ~/Library/Python/3.9/lib/python/site-packages/qdrant_client/http/api_client.py:215, in BaseMiddleware.__call__(self, request, call_next)
#     214 def __call__(self, request: Request, call_next: Send) -> Response:
# --> 215     return call_next(request)
#
# File ~/Library/Python/3.9/lib/python/site-packages/qdrant_client/http/api_client.py:118, in ApiClient.send_inner(self, request)
#     116     response = self._client.send(request)
#     117 except Exception as e:
# --> 118     raise ResponseHandlingException(e)
#     119 return response
#
# ResponseHandlingException: [Errno 8] nodename nor servname provided, or not known

# %%
df.columns
# Out:
# Index(['nombre', 'slug', 'collection_id', 'locale_id', 'item_id', 'created_on',
#        'updated_on', 'published_on', 'precio', 'imagen_del_producto',
#        'categoria', 'descripción', 'maridaje_1', 'maridaje_2', 'notas_de_cata',
#        'temperatura_de_servicio', 'pasillo', 'tipo', 'región',
#        'cepa_principal', 'ocasión', 'bodega', 'denominación', 'peso_/_volumen',
#        'gr/ml', 'item_id', 'precio_descuento', 'categories', 'precios',
#        'descuento', 'descuento_2x1', 'descuento_3x2', 'ciudad',
#        'productoreserva', 'descuento%off'],
#       dtype='object')

# %%
# Step 1 - Inspect products with "prosecco" in product_name
print("\n🔍 Checking indexed Prosecco products by name:\n")

results, _ = client.scroll(
    collection_name=collection_name,
    limit=100,
    with_payload=True
)

prosecco_items = [
    r for r in results if "prosecco" in str(r.payload.get("product_name", "")).lower()
]

if not prosecco_items:
    print("❌ No Prosecco products found in product_name.")
else:
    for i, item in enumerate(prosecco_items, 1):
        print(f"\n#{i}")
        for k, v in item.payload.items():
            print(f"{k}: {v}")
# Out:
# 🔍 Checking indexed Prosecco products by name:
#
#
# #1
# product_name: Prosecco Sior Piero
# bodega: V8+
# region: Veneto
# tipo: Espumoso
# precio: 115000.0
# notas: De un color pajizo brillante, burbujas finas y persistentes, aromas delicados que recuerdan notas Florales y frutales que recuerdan a la manzanilla, durazno, peras. En el paladar es fresco, elegante con una pequeña cantidad de azúcar residual que es balanceado por la acidez.
# descripcion: ELABORACIÓN DEL VINO   Después de la vendimia manual, la uva es separada de los raspones y son estrujadas suavemente. La fermentación toma lugar en tanques de acero inoxidable, a temperatura controlada para preservar los aromas. La segunda fermentación se lleva a cabo en autoclaves de acero por aproximadamente 35 días. VARIEDAD DE UVA Y ÁREA DE PRODUCCIÓN   Glera 100%. Los viñedos se encuentran en las colinas de Valdobbiadene, la patria del Prosecco, que son las burbujas más famosas de Italia. Aromas inconfundibles de este estilo de vino. La región es privilegiada por tener un clima único,\npues tiene la influencia del mar adrático, y de las colinas prealpinas. Los viñedos generalmente están plantados con orientación al sur, que les confiere una mejor exposición solar. GRADUACIÓN ALCOHÓLICA   12,5% vol.
# maridaje: Pasta y Pizza y Postre
# category: Vinos
# alternate_names:
#
# #2
# product_name: Aspide + Prosecco
# bodega: Sior Sandro
# region:
# tipo:
# precio: 169000.0
# notas:
# descripcion: Combo Aperol Spritz Prosecco + Aspide
# maridaje:
# category:
# alternate_names:
#
# #3
# product_name: Prosecco Sior Sandro
# bodega: V8+
# region: Veneto
# tipo: Espumoso
# precio: 100000.0
# notas: De un color amarillo pálido, burbujas finas y persistentes, aromas que recuerdan a los frutos de hueso, durazno, albaricoque, florales, que recuerdan a la manzanilla. En el paladar es agradable y fresco.
# descripcion: ELABORACIÓN DEL VINO   Después de la vendimia manual, la uva es separada de los raspones y son estrujadas suavemente. La fermentación toma lugar en tanques de acero inoxidable, a temperatura controlada para preservar los aromas. La segunda fermentación se lleva a cabo en autoclaves de acero por aproximadamente 35 días. VARIEDAD DE UVA Y ÁREA DE PRODUCCIÓN   Glera 100%. Los viñedos se encuentran en las colinas de la región del véneto, en la zona del Prosecco. La región es privilegiada por tener un clima único, pues tiene la influencia del mar adrático, y de las colinas prealpinas. Los viñedos generalmente están plantados con orientación al sur, que les confiere una mejor exposición solar. GRADUACIÓN ALCOHÓLICA   12,5% vol
# maridaje: Pasta y Pizza y Postre
# category: Vinos
# alternate_names:

# %%
items
# Out:
# [{'id': '6823fa2dd9f312dbdbb2de73',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': '2025-05-14T02:04:29.094Z',
#   'lastUpdated': '2025-05-14T02:04:29.094Z',
#   'createdOn': '2025-05-14T02:04:29.094Z',
#   'isArchived': False,
#   'isDraft': False,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False,
#    'precio-descuento': '172000',
#    'gr-ml': 'Mililitro por $245,71',
#    'precio': '137600',
#    'pasillo': 'Vinos',
#    'bodega': 'Silvio Carta',
#    'name': 'Vermouth Blanco',
#    'descripcion': '<p>Esta inspirado en las recetas clásicas de principios del siglo XX. Sunombre y estética evocan la elegancia retro y el espíritu lúdico delos bares italianos de la década de 1920, elaborado coningredientes de origen sardo. Cuenta con Infusión de hierbasaromáticas, cáscaras de cítricos sardos, flores blancas y especiasligeras.Perfecto como aperitivo con hielo y una rodaja de limón, o encócteles como el Martini Bianco o el Bianco Spritz.La etiqueta y el nombre hacen referencia al año de nacimiento deSilvio Carta (1929), rindiendo homenaje al fundador y a la tradiciónde la casa.</p>',
#    'categoria': 'Vinos',
#    'peso-volumen': '700',
#    'slug': 'vermouth-blanco',
#    'categories': '6660ca3823741b8f165309d1',
#    'imagen-del-producto': {'fileId': '6823f941e0b84ef009f120d1',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/6823f941e0b84ef009f120d1_Vermouth%20Blanco.webp',
#     'alt': None}}},
#  {'id': '6823f83f37e7dd18f6e1d4ed',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': '2025-05-14T12:37:08.834Z',
#   'lastUpdated': '2025-05-14T12:37:08.834Z',
#   'createdOn': '2025-05-14T01:56:15.214Z',
#   'isArchived': False,
#   'isDraft': False,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False,
#    'gr-ml': 'Mililitro por $245,71',
#    'precio': '137600',
#    'pasillo': 'Vinos',
#    'bodega': 'Silvio Carta',
#    'name': 'Vermouth Rojo',
#    'descripcion': '<p>Se elabora a partir de Vernaccia di Oristano, un vino típico deCerdeña con crianza oxidativa, que aporta profundidad ysingularidad. Cuenta con botánicos autóctonos que incluye más de30 hierbas sardas, como el mirto, tomillo, hinojo salvaje y cítricoslocales.Estilo artesanal: La receta sigue un método tradicional con infusionesnaturales y maceraciones largas, sin aromas artificiales. Ideal paracócteles clásicos como el Negroni, Manhattan o Americano, perotambién se disfruta solo con hielo o como aperitivo.Intenso y elegante, dominado por notas de hierbas aromáticassardas, ajenjo, cítricos confitados, raíces y especias dulces comocanela y clavo</p>',
#    'categoria': 'Vinos',
#    'peso-volumen': '700 ml',
#    'categories': '6660ca3823741b8f165309d1',
#    'imagen-del-producto': {'fileId': '6823f75e9019171deb9eb296',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/6823f75e9019171deb9eb296_Vermouth-Rojo_1.webp',
#     'alt': None},
#    'slug': 'vermouth-rojo',
#    'precio-descuento': '172000'}},
#  {'id': '6823f71280a8d9de4f1a43f8',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': '2025-05-14T01:58:12.446Z',
#   'lastUpdated': '2025-05-14T01:58:12.446Z',
#   'createdOn': '2025-05-14T01:51:14.463Z',
#   'isArchived': False,
#   'isDraft': False,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False,
#    'precio-descuento': '212000',
#    'precio': '169600',
#    'pasillo': 'Vinos',
#    'name': 'Gin Pigskin',
#    'descripcion': '<p>Contiene botánicos locales como enebro sardo y una mezcla dehierbas mediterráneas seleccionadas, como mirto, hinojo y salvia.Posee un envejecimiento especial: Se madura brevemente enbarricas de castaño centenario que previamente contenían Vernacciadi Oristano, aportando complejidad.Cuenta con una graduación alcohólica: 40% vol, ideal para respetarel perfil London Dry sin perder su carácter local. “Pigskin” alude aljabalí salvaje de Cerdeña, un animal icónico de la isla, presente en laetiqueta y en el espíritu rústico y auténtico del gin.</p>',
#    'categoria': 'Vinos',
#    'categories': '6660ca3823741b8f165309d1',
#    'imagen-del-producto': {'fileId': '6823f6eb5d9db30ec9e5008f',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/6823f6eb5d9db30ec9e5008f_Gin%20Pigskin.webp',
#     'alt': None},
#    'slug': 'gin-pigskin',
#    'gr-ml': 'Mililitro por $302,85 ',
#    'peso-volumen': '700 ml',
#    'bodega': 'Silvio Carta'}},
#  {'id': '6823f68302f24dd9e4b9df4f',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': '2025-05-14T01:59:01.100Z',
#   'lastUpdated': '2025-05-14T01:59:01.100Z',
#   'createdOn': '2025-05-14T01:48:51.602Z',
#   'isArchived': False,
#   'isDraft': False,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False,
#    'precio-descuento': '22900',
#    'gr-ml': '$327,14 por ml',
#    'precio': '183200',
#    'name': 'Boigin Saffron',
#    'descripcion': '<p>Utiliza azafrán sardo de alta calidad, lo que le da un perfilaromático y cromático distintivo. Producido por SilvioCarta, una destilería histórica fundada en 1950, ubicadaen Baratili San Pietro, Cerdeña. Cuenta con un aGraduación alcohólica 40% vol, es un gin equilibrado paradestacar los botánicos sin perder intensidad.Es un London Dry Gin en espíritu, pero con un toqueinnovador gracias al uso de ingredientes locales, que lohacen único entre los gins artesanales italianos.</p>',
#    'categoria': 'Vinos',
#    'peso-volumen': '700 ml',
#    'categories': '6660ca3823741b8f165309d1',
#    'imagen-del-producto': {'fileId': '6823f5d73158646dd6226ec1',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/6823f5d73158646dd6226ec1_Boigin%20Saffron.webp',
#     'alt': None},
#    'slug': 'boigin-saffron',
#    'bodega': 'Silvio Carta'}},
#  {'id': '67e03ce522349689dfa5d528',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': '2025-05-05T23:32:45.915Z',
#   'lastUpdated': '2025-04-29T15:40:48.836Z',
#   'createdOn': '2025-03-23T16:55:01.562Z',
#   'isArchived': False,
#   'isDraft': False,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False,
#    'precio': '46000',
#    'pasillo': 'Quesos',
#    'name': 'Mascarpone 500gr',
#    'descripcion': '<p>El mascarpone, típicamente lombardo,se elabora respetando el proceso tradicional que realzasu cremosidad natural.Elaborado a partir de crema de leche, su sabor es delicado,con notas ligeramente dulces y mantecosas que lo hacenversátil para preparaciones tanto dulces como saladas.Ideal para postres como el clásico tiramisú, el mascarponetambién puede realzar platos salados como salsas cremosas,risottos o incluso ser utilizado como un deliciosoacompañamiento para frutas frescas o panes artesanales.</p>',
#    'categoria': 'Quesos',
#    'ciudad': 'Bogota',
#    'peso-volumen': '$67 por gramo',
#    'imagen-del-producto': {'fileId': '67e03c870e5925bb58b48787',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/67e03c870e5925bb58b48787_Mascarpone%20Virgilio.png',
#     'alt': None},
#    'categories': '6660ca3823741b8f165309d3',
#    'slug': 'mascarpone-500gr'}},
#  {'id': '67e03a6483dff41b3d812130',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': None,
#   'lastUpdated': '2025-04-07T22:59:15.695Z',
#   'createdOn': '2025-03-23T16:44:20.428Z',
#   'isArchived': True,
#   'isDraft': False,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False,
#    'precio-descuento': '270000',
#    'precio': '209000',
#    'name': 'Promo Torre Rosazza (3 vinos)',
#    'categoria': 'Vinos',
#    'imagen-del-producto': {'fileId': '67e03a5ada78afcaecd50cb7',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/67e03a5ada78afcaecd50cb7_Pieza%20Combo-20.jpg',
#     'alt': None},
#    'categories': '6660ca3823741b8f165309d1',
#    'slug': 'promo-torre-rosazza',
#    'bodega': 'Torre Rosazza',
#    'descripcion': '<p id="">Tras una cosecha a finales de agosto y un suave prensado, el proceso de vinificación se realiza en blanco separando inmediatamente los hollejos de los mostos y le sigue una fermentación alcohólica en depósitos de acero inoxidable a una temperatura controlada de 15-16 °C. El afinamiento se realiza sobre lías refinadas durante al menos 3 meses. Muy importante para el resultado final es la “ponca”: suelo margoso que se alterna con capas de arenisca, rico en minerales y pobre en materia orgánica. Este terreno es el que permite un desarrollo aromático en el bouquet de este vino.</p><p>\u200d</p><p>Pinot grigio + Traminer + Pinot Nero</p>',
#    'temperatura-de-servicio': '15-20C',
#    'tipo': 'Blanco',
#    'gr-ml': '$132 por ml'}},
#  {'id': '67bf19088c3f5d509954d232',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': '2025-03-21T04:51:14.899Z',
#   'lastUpdated': '2025-03-21T04:51:14.899Z',
#   'createdOn': '2025-02-26T13:37:12.400Z',
#   'isArchived': False,
#   'isDraft': False,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False,
#    'descripcion': '<p id="">De color rojo rubí brillante con sutiles reflejos granates, este Pinot Nero se caracteriza por su elegancia y complejidadaromática. </p>',
#    'precio': '59000',
#    'bodega': 'Torre Rosazza',
#    'name': 'Pinot Nero',
#    'categoria': 'Vinos',
#    'imagen-del-producto': {'fileId': '67bf180b8690788a35859739',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/67bf180b8690788a35859739_Pinot%20Nero%20-%20Torre%20Rosazza.png',
#     'alt': None},
#    'categories': '66635db36d9753905f695788',
#    'slug': 'pinot-nero',
#    'gr-ml': '$132 por ml',
#    'notas-de-cata': 'En nariz, ofrece notas intensas de frutos rojos como frambuesa, cereza y grosella, acompañadas notas florales de violeta y un delicado toque especiado de pimienta negra. En boca es equilibrada y sedoso, contaninos finos y unaacidez fresca que resalta su estructura. Su final es persistente y armonioso.\u200d',
#    'pasillo': 'Vinos',
#    'region': 'Friuli Grave',
#    'temperatura-de-servicio': '15-20°C',
#    'tipo': 'Tinto',
#    'precio-descuento': '99000'}},
#  {'id': '67bf17cce79602e51871cb68',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': '2025-03-21T04:51:56.411Z',
#   'lastUpdated': '2025-03-21T04:51:56.411Z',
#   'createdOn': '2025-02-26T13:31:56.706Z',
#   'isArchived': False,
#   'isDraft': False,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False,
#    'gr-ml': '$132 por ml',
#    'temperatura-de-servicio': '15-20°C',
#    'precio': '59000',
#    'pasillo': 'Vinos',
#    'bodega': 'Torre Rosazza',
#    'name': 'Traminer ',
#    'categoria': 'Vinos',
#    'imagen-del-producto': {'fileId': '67bf17443f298d9d76006591',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/67bf17443f298d9d76006591_Traminer%20-%20Torre%20Rosazza.png',
#     'alt': None},
#    'categories': '66635db36d9753905f695788',
#    'slug': 'traminer',
#    'cepa-principal': 'Traminer',
#    'descripcion': '<p id="">De color dorado brillante, este Traminer destaca por su expresividad aromática y elegancia</p>',
#    'notas-de-cata': 'En nariz, despliega un bouquet intenso con notas florales de jazmín, acompañado de frutas exóticas como lichi, maracuyá y cítricos maduros. Un delicado toque especiado de jengibre y pimienta blanca aporta complejidad. En boca es envolvente y armonioso, con una acidez vibrante que resalta su frescura.',
#    'peso-volumen': '750ml',
#    'region': 'Friuli Grave',
#    'tipo': 'Tinto',
#    'precio-descuento': '99000'}},
#  {'id': '67bbfa487f15dfc01f10d49a',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': '2025-03-12T23:40:37.558Z',
#   'lastUpdated': '2025-03-12T23:40:37.558Z',
#   'createdOn': '2025-02-24T04:49:12.465Z',
#   'isArchived': False,
#   'isDraft': False,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False,
#    'gr-ml': '$666.67 por ml',
#    'temperatura-de-servicio': '15-20°C',
#    'precio': '500000',
#    'pasillo': 'Vinos',
#    'bodega': 'Hofstatter',
#    'name': 'Barthenau Vigna',
#    'notas-de-cata': 'El aroma que recuerda a guindas y frambuesa se ve realzado por un delicado toque de vainilla y especias',
#    'categoria': 'Vinos',
#    'cepa-principal': 'Pinot Nero',
#    'region': 'Alto Adige',
#    'tipo': 'Tinto',
#    'denominacion': 'DOC',
#    'peso-volumen': '750',
#    'imagen-del-producto': {'fileId': '67bbf9ad3507c270ff17f918',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/67bbf9ad3507c270ff17f918_Barthenau%20Vigna.png',
#     'alt': None},
#    'categories': '6660ca3823741b8f165309d1',
#    'slug': 'barthenau-vigna'}},
#  {'id': '67bbf9825ce879aacaa08f34',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': '2025-03-12T23:40:16.691Z',
#   'lastUpdated': '2025-03-12T23:40:16.691Z',
#   'createdOn': '2025-02-24T04:45:54.714Z',
#   'isArchived': False,
#   'isDraft': False,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False,
#    'gr-ml': '$392 por ml',
#    'temperatura-de-servicio': '15-20°C',
#    'precio': '294000',
#    'pasillo': 'Vinos',
#    'bodega': 'Hofstatter',
#    'name': 'Mazon Reserva',
#    'descripcion': '<p id="">De color rojo rubí intenso con destellos granates. Presenta aromas complejos y elegantes de frutas rojas como cerezas y bayas negras, acompañadas denotas especiadas (pimienta negra, canela) y sutiles toques de vainilla, cacao y cuero,resultado de su crianza en roble. También aparecen matices terrosos y minerales que reflejan su terroir. Los taninos son finos, suaves e integrados.Los sabores de frutas rojas y especias se combinan con notas de tostado y madera, dejando un final largo,elegante y persistente.</p>',
#    'notas-de-cata': 'Los sabores de frutas rojas y especias se combinan con notas de tostado y madera, dejando un final largo, elegante y persistente',
#    'categoria': 'Vinos',
#    'cepa-principal': 'Pinot Nero',
#    'region': 'Alto Adige',
#    'tipo': 'Tinto',
#    'denominacion': 'DOC',
#    'peso-volumen': '750',
#    'imagen-del-producto': {'fileId': '67bbf9039964bb570dc2bdd5',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/67bbf9039964bb570dc2bdd5_Mazon%20pinot%20Nero.png',
#     'alt': None},
#    'categories': '6660ca3823741b8f165309d1',
#    'slug': 'mazon-reserva'}},
#  {'id': '67bbf8ae5a5c00b87042efb8',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': '2025-03-21T04:44:51.931Z',
#   'lastUpdated': '2025-03-21T04:44:51.931Z',
#   'createdOn': '2025-02-24T04:42:22.983Z',
#   'isArchived': False,
#   'isDraft': False,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False,
#    'gr-ml': '$182.6 por ml',
#    'temperatura-de-servicio': "15'20°C",
#    'precio': '99000',
#    'pasillo': 'Vinos',
#    'bodega': 'Hofstatter',
#    'name': 'Mezcan Vigneti',
#    'descripcion': '<p>De color rojo rubí brillante, con matices granates en los bordes, lo queindica su juventud y frescura. Presenta aromas delicados y complejos de frutas rojas,como fresas y cerezas, acompañados de notas florales y un ligero toque terroso. Con el tiempo en la copa, pueden aparecer matices de especias y hierbas que enriquecen superfil aromático. Es un vino elegante y equilibrado, con una acidez fresca que realza sucarácter frutal. Los taninos son suaves y bien integrados, ofreciendo una textura sedosa. El final es persistente, con sabores de frutas rojas y un toque mineral. el microclima único del altiplano de Mazón proporcionan las condiciones ideales paraproducir un Pinot Noir de calidad mundial.</p>',
#    'notas-de-cata': ' Presenta aromas complejos y elegantes de frutas rojas como cerezas y bayas negras, acompañadas de notas especiadas (pimienta negra, canela) y sutiles toques de vainilla, cacao y cuero, resultado de su crianza en roble',
#    'categoria': 'Vinos',
#    'cepa-principal': 'Pinot Nero',
#    'region': 'Trentino Alto Adige ',
#    'tipo': 'Tinto',
#    'denominacion': 'DOC',
#    'peso-volumen': '750',
#    'imagen-del-producto': {'fileId': '67bbf80c781f135c7f4216e3',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/67bbf80c781f135c7f4216e3_Mezcan%20Pinot%20Negro.png',
#     'alt': None},
#    'categories': '66635db36d9753905f695788',
#    'slug': 'mezcan-vigneti',
#    'precio-descuento': '137000'}},
#  {'id': '67bbf7466cbbed2183ea540d',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': '2025-03-12T23:39:59.448Z',
#   'lastUpdated': '2025-03-12T23:39:59.448Z',
#   'createdOn': '2025-02-24T04:36:22.072Z',
#   'isArchived': False,
#   'isDraft': False,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False,
#    'gr-ml': '$182.6 por ml',
#    'temperatura-de-servicio': '15-20°C',
#    'precio': '137000',
#    'pasillo': 'Vinos',
#    'bodega': 'Hofstatter',
#    'name': 'Merlot Alto Adige ',
#    'descripcion': '<p id="">De color rojo rubí profundo con reflejos púrpuras, este Merlot muestra una intensidad visual que anticipa su carácter robusto. Presenta aromas intensos y complejos que combinan frutas negras maduras, como ciruelas y moras, con toques decerezas oscuras. También se perciben notas especiadas de pimienta negra y clavo,junto con sutiles matices de cacao, tabaco, y un delicado fondo terroso. En boca esseco, con una textura aterciopelada y taninos bien estructurados pero suaves</p>',
#    'notas-de-cata': ' Presenta aromas intensos y complejos que combinan frutas negras maduras, como ciruelas y moras, con toques de cerezas oscuras',
#    'categoria': 'Vinos',
#    'region': 'Alto Adige',
#    'tipo': 'Tinto',
#    'denominacion': 'DOC',
#    'slug': 'merlot-alto-adige',
#    'imagen-del-producto': {'fileId': '67bbf68ccd6e05ec201ff856',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/67bbf68ccd6e05ec201ff856_Merlot%20Alto%20Adige.png',
#     'alt': None},
#    'categories': '6660ca3823741b8f165309d1'}},
#  {'id': '67b895502cb7b5f32a19a5ff',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': None,
#   'lastUpdated': '2025-02-25T16:57:41.421Z',
#   'createdOn': '2025-02-21T15:01:36.992Z',
#   'isArchived': False,
#   'isDraft': True,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False,
#    'precio': '0',
#    'name': 'Producto de testeo de flujo',
#    'imagen-del-producto': {'fileId': '67b89547c0d14e977f637527',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/67b89547c0d14e977f637527_WhatsApp%20Image%202024-10-27%20at%203.32.56%20PM.jpeg',
#     'alt': None},
#    'slug': 'producto-de-testeo-de-flujo',
#    'categories': '6660caffc04494865e3bce5f'}},
#  {'id': '67b6709183b9b745162ef761',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': '2025-03-12T23:39:02.315Z',
#   'lastUpdated': '2025-03-12T23:39:02.315Z',
#   'createdOn': '2025-02-20T00:00:17.224Z',
#   'isArchived': False,
#   'isDraft': False,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False,
#    'gr-ml': 'Mil a $1084',
#    'temperatura-de-servicio': '15 - 20C°',
#    'precio': '813000',
#    'pasillo': 'Vinos',
#    'bodega': 'Collazzi',
#    'name': 'Collazzi Ferro',
#    'descripcion': '<p>De color rojo rubí intenso con destellos violáceos, que revelan su juventud y frescura. Presentan aromas que despliegan una explosión de notas frutales,destacando cereza, frambuesa y ciruela madura, acompañadas de matices especiados de pimienta negra y un toque sutil de hierbas mediterráneas. La complejidad se ve enriquecida por notas de vainilla y tostados, resultado de su crianza en barrica. Es un vino con un final eterno y elegante.</p>',
#    'notas-de-cata': 'Presentan aromas que despliegan una explosión de notas frutales,destacando cereza, frambuesa y ciruela madura, acompañadas de matices especiados de pimienta negra y un toque sutil de hierbas mediterráneas',
#    'categoria': 'Vinos',
#    'cepa-principal': 'Petit Verdot',
#    'region': 'Toscana',
#    'denominacion': 'IGT',
#    'categories': '6660ca3823741b8f165309d1',
#    'imagen-del-producto': {'fileId': '67b66e73b6054b7759787afc',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/67b66e73b6054b7759787afc_Collazzi%20Ferro.png',
#     'alt': None},
#    'slug': 'collazzi-ferro',
#    'tipo': 'Tinto'}},
#  {'id': '67b66df9198f004787ea8553',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': '2025-03-12T23:35:53.471Z',
#   'lastUpdated': '2025-03-12T23:35:53.471Z',
#   'createdOn': '2025-02-19T23:49:13.401Z',
#   'isArchived': False,
#   'isDraft': False,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False,
#    'gr-ml': 'Mil a $470.6',
#    'temperatura-de-servicio': '15 y 20 grados C°',
#    'precio': '363000',
#    'pasillo': 'Vinos',
#    'name': 'Collazzi Rosso Toscana',
#    'descripcion': '<p>De color rojo rubí intenso. Presenta aromas frutales como cerezas,ciruelas y moras, acompañados de notas florales y especias. Con el tiempo, pueden surgir matices de vainilla y tostados, gracias a su crianza en barrica.Sabor: En boca es un vino bien equilibrado, con una acidez refrescante y taninos suaves, final ligeramente especiado y persistente. La madera está integrada, lo que aporta complejidad sin opacar la fruta</p>',
#    'categoria': 'Vinos',
#    'cepa-principal': 'Cabernet Sauvignon',
#    'region': 'Toscana',
#    'denominacion': 'IGT',
#    'imagen-del-producto': {'fileId': '67b66cbabf5b9788ab8a06b4',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/67b66cbabf5b9788ab8a06b4_Collazzi%20Rosso%20Toscana.png',
#     'alt': None},
#    'categories': '6660ca3823741b8f165309d1',
#    'slug': 'collazzi-rosso-toscana',
#    'tipo': 'Tinto'}},
#  {'id': '67b66c8f4cb91562c0953de5',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': '2025-03-12T23:35:38.943Z',
#   'lastUpdated': '2025-03-12T23:35:38.943Z',
#   'createdOn': '2025-02-19T23:43:11.566Z',
#   'isArchived': False,
#   'isDraft': False,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False,
#    'gr-ml': 'Mil a $200',
#    'precio': '150000',
#    'bodega': 'Collazzi',
#    'name': 'Collazzi Libertá Toscana',
#    'descripcion': '<p>Un vino que refleja la filosofía de libertad y creatividad de la finca Collazzi. De color rojo rubí profundo con reflejos violáceos. Presenta aromas intensos y complejos que combinan frutos rojos maduros como cerezas y ciruelas, con notas especiadas de vainilla, canela y un toque de regaliz, complementadas por un fondo decacao y tabaco. En boca, es redondo, sedoso y bien estructurado. Los taninos son suaves y elegantes, con una acidez equilibrada que aporta frescura.</p>',
#    'notas-de-cata': 'Presenta aromas intensos y complejos que combinan frutos rojos maduros como cerezas y ciruelas',
#    'categoria': 'Vinos',
#    'cepa-principal': 'Merlot',
#    'region': 'Toscana',
#    'denominacion': 'IGT',
#    'imagen-del-producto': {'fileId': '67b66b7c26e1abba88648838',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/67b66b7c26e1abba88648838_Collazzi%20Libert%C3%A1%20Toscana.png',
#     'alt': None},
#    'categories': '6660ca3823741b8f165309d1',
#    'slug': 'collazzi-liberta-toscana',
#    'tipo': 'Tinto'}},
#  {'id': '67b66b3ddeef0e34a9d7c842',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': '2025-03-21T04:50:37.300Z',
#   'lastUpdated': '2025-03-21T04:50:37.300Z',
#   'createdOn': '2025-02-19T23:37:33.156Z',
#   'isArchived': False,
#   'isDraft': False,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False,
#    'gr-ml': 'Mil a $182.7',
#    'precio': '99000',
#    'bodega': 'Collazzi',
#    'name': 'Collazzi Bastioni Chianti',
#    'descripcion': '<p>De color rojo rubí intenso con reflejos granate. Presenta aromas elegantes y complejos que combinan notas de frutas rojas frescas como cerezas y frambuesas, con toques de violetas, especias dulces, tabaco y un delicado matiz terroso. En boca, es estructurado y armonioso. Ofrece taninos firmes pero bien integrados, una acidez viva que aporta frescura y sabores persistentes de frutos rojos,hierbas mediterráneas y un sutil toque de roble tostado. Final largo y envolvente.</p>',
#    'categoria': 'Vinos',
#    'cepa-principal': 'Sangiovese',
#    'region': 'Chianti',
#    'denominacion': 'DOCG',
#    'imagen-del-producto': {'fileId': '67b66aaf9b1ef2ee60955604',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/67b66aaf9b1ef2ee60955604_Collazzi%20Bastioni%20Chianti.png',
#     'alt': None},
#    'categories': '66635db36d9753905f695788',
#    'slug': 'collazzi-bastioni-chianti',
#    'pasillo': 'Vinos',
#    'tipo': 'Tinto',
#    'precio-descuento': '137000'}},
#  {'id': '67b66a72bbf7fe75d958b4e2',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': None,
#   'lastUpdated': '2025-03-03T23:21:49.757Z',
#   'createdOn': '2025-02-19T23:34:10.483Z',
#   'isArchived': True,
#   'isDraft': True,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False,
#    'gr-ml': 'Mil a $182.7',
#    'precio': '137000',
#    'pasillo': 'Vinos',
#    'bodega': 'Collazzi',
#    'name': 'Collazzi Otto Muri',
#    'descripcion': '<p id="">De color amarillo limón brillante con reflejos dorados. Presenta aromas frescos con notas de flores blancas, frutas tropicales como piña y maracuyá, melocotón, pera madura, toque cítrico y un sutil toque mineral que evoca el suelo de origen. De cuerpo medio y bien equilibrado complementados por una acidez refrescante y un final persistente.</p>',
#    'notas-de-cata': 'Presenta aromas frescos con notas de flores blancas, frutas tropicales como piña y maracuyá, melocotón, pera madura, toque cítrico',
#    'categoria': 'Vinos',
#    'cepa-principal': 'Fiano',
#    'region': 'Toscana ',
#    'denominacion': 'IGT',
#    'peso-volumen': '750',
#    'imagen-del-producto': {'fileId': '67b6687dbbf7fe75d956dba7',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/67b6687dbbf7fe75d956dba7_Collazzi%20Otto%20Muri.png',
#     'alt': None},
#    'categories': '6660ca3823741b8f165309d1',
#    'slug': 'collazzi-otto-muri',
#    'tipo': 'Blanco'}},
#  {'id': '6791b94b28ed58d7ddf64fed',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': None,
#   'lastUpdated': '2025-01-26T02:12:07.971Z',
#   'createdOn': '2025-01-23T03:36:43.014Z',
#   'isArchived': True,
#   'isDraft': False,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False,
#    'precio': '14000',
#    'descripcion': '<p id="">Elaborados con trigo de alta calidad y extruídos en bronce, &nbsp;aseguran una excelente absorción de los condimentos, brindando una experiencia deliciosa y satisfactoria en cada bocado. Perfectos para acompañar salsas ricas o platos al horno.</p><p id="">\u200d</p>',
#    'gr-ml': 'Gramo a $28',
#    'name': 'RADIATORI - GAROFALO 500G',
#    'imagen-del-producto': {'fileId': '6791b945fb998feb3e7f62f8',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/6791b945fb998feb3e7f62f8_RADIATORI%20%E2%80%93%20500%20g.webp',
#     'alt': None},
#    'slug': 'radiatori---garofalo-500g',
#    'categories': '6660cae85768b4de8082734e'}},
#  {'id': '6791b8d92c849e7dae61e2d6',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': None,
#   'lastUpdated': '2025-02-22T17:16:13.566Z',
#   'createdOn': '2025-01-23T03:34:49.244Z',
#   'isArchived': True,
#   'isDraft': True,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False,
#    'precio': '80000',
#    'descripcion': '<p id=""><strong id="">DESCRIPCIÓN</strong> Línea exclusiva diseñada por Maestri Milano y la bodega familiar Assuli para Colombia, dos etiquetas que quieren representar a la fuerza y elegancia de los vinos de Sicilia.La familia Caruso, dueña de 120 hectáreas de tierra, desde hace varios años ha convertido su producción al método orgánico para valorar la autenticidad del<em id=""> terroir</em> local. El viñedo se encuentra en el lado occidental de Sicilia, en una zona reconocida por su centenaria historia vitivinícola: el sol, la luz, la alta mineralidad del suelo, los perfumes mediterráneos que trae el viento caracterizan vinos de gran personalidad. Trame D´oro</p>',
#    'gr-ml': '33',
#    'name': 'Producto de testeo de flujo',
#    'imagen-del-producto': {'fileId': '67ace0ecbac02ce79d45c36e',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/67ace0ecbac02ce79d45c36e_6661dfd49d136a73ff7dfd2f_caja1-1.jpeg',
#     'alt': None},
#    'slug': 'caja-de-madera-para-vinosss',
#    'categories': '66615043b65cd9e10cf74fa9',
#    'categoria': 'cajas',
#    'item-id': '66615043b65cd9e10cf74fa9',
#    'precio-descuento': '34000'}},
#  {'id': '6791b82351e5a36450294d76',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': '2025-01-29T14:30:16.258Z',
#   'lastUpdated': '2025-01-23T13:45:12.135Z',
#   'createdOn': '2025-01-23T03:31:47.719Z',
#   'isArchived': False,
#   'isDraft': False,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False,
#    'precio': '14000',
#    'descripcion': '<p>Su estructura única permite que las salsas se absorban de manera excepcional, ofreciendo una experiencia de sabor intensa. Perfectas para acompañar salsas espesas o platos al horno, brindan una textura firme y un sabor delicioso en cada bocado.</p>',
#    'gr-ml': 'Gramo a $28',
#    'name': 'CASARECCE - GAROFALO 500G',
#    'imagen-del-producto': {'fileId': '6791b7dd6a1db71ef14172b1',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/6791b7dd6a1db71ef14172b1_CASARECCE%20%E2%80%93%20500%20g.webp',
#     'alt': None},
#    'slug': 'casarecce---garofalo-500g',
#    'categories': '6660cae85768b4de8082734e'}},
#  {'id': '6791b7ab454bb2ea9c9d2cd7',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': '2025-01-29T14:30:16.258Z',
#   'lastUpdated': '2025-01-23T13:47:19.333Z',
#   'createdOn': '2025-01-23T03:29:47.441Z',
#   'isArchived': False,
#   'isDraft': False,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False,
#    'descripcion': '<p id="">Elaborados con trigo de alta calidad y extruídos en bronce. &nbsp;Son ideales para platos con salsas generosas o en preparaciones al horno, brindando una experiencia rica y satisfactoria en cada bocado.</p>',
#    'gr-ml': 'Gramo a $28',
#    'name': 'LUMACA RIGATA - GAROFALO 500G',
#    'slug': 'lumaca-rigata---garofalo-500g',
#    'imagen-del-producto': {'fileId': '6791b77383e9ee3f7ae003ff',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/6791b77383e9ee3f7ae003ff_Lumaca%20Rigata.webp',
#     'alt': None},
#    'precio': '14000',
#    'categories': '6660cae85768b4de8082734e'}},
#  {'id': '6791b71b793f67cbc54ad808',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': None,
#   'lastUpdated': '2025-02-08T12:07:03.939Z',
#   'createdOn': '2025-01-23T03:27:23.802Z',
#   'isArchived': True,
#   'isDraft': True,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False,
#    'precio': '14000',
#    'descripcion': '<p id="">Elaborados con trigo de alta calidad y extruídos en bronce. Son ideales para acompañar salsas densas o platos al horno, proporcionando una experiencia culinaria completa y deliciosa.</p>',
#    'gr-ml': 'Gramo a $28',
#    'name': 'MEZZE MANICHE RIGATE - GAROFALO 500G',
#    'imagen-del-producto': {'fileId': '6791b6d9ac4378cde99cd7c7',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/6791b6d9ac4378cde99cd7c7_MEZZE%20MANICHE%20RIGATE%20-%20GAROFALO%20500G.webp',
#     'alt': None},
#    'slug': 'mezze-maniche-rigate---garofalo-500g',
#    'categories': '6660cae85768b4de8082734e'}},
#  {'id': '6791b6b7218eed54a4aadd91',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': '2025-01-29T14:30:16.258Z',
#   'lastUpdated': '2025-01-23T13:51:26.316Z',
#   'createdOn': '2025-01-23T03:25:43.779Z',
#   'isArchived': False,
#   'isDraft': False,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False,
#    'precio': '18000',
#    'descripcion': '<p id="">Elaborados con trigo de alta calidad y extruídos en bronce, son ideales para ser rellenos con ingredientes exquisitos y disfrutar en platos gratinados o al horno. </p><p id="">\u200d</p>',
#    'gr-ml': 'Gramo a $36',
#    'name': 'CONCHIGLIONI - GAROFALO 500G',
#    'imagen-del-producto': {'fileId': '6791b65a2c849e7dae5f9099',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/6791b65a2c849e7dae5f9099_CONCHIGLIONI%20%E2%80%93%20500%20G.webp',
#     'alt': None},
#    'slug': 'conchiglioni---garofalo-500g',
#    'categories': '6660cae85768b4de8082734e'}},
#  {'id': '6791b62dac4378cde99c27f6',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': None,
#   'lastUpdated': '2025-03-26T15:04:30.631Z',
#   'createdOn': '2025-01-23T03:23:25.062Z',
#   'isArchived': True,
#   'isDraft': True,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False,
#    'precio': '21000',
#    'descripcion': '<p id="">Los Linguine Gluten Free Garofalo son elaborados con una mezcla de harinas seleccionadas para ofrecer una textura firme y una excelente capacidad de absorción de salsas. Perfectos para quienes siguen una dieta sin gluten, mantienen la tradición italiana de calidad y sabor en cada plato.</p><p id="">\u200d</p>',
#    'gr-ml': 'Gramo a $52',
#    'name': 'LINGUINE GLUTEN FREE - GAROFALO 400G',
#    'slug': 'linguine-gluten-free---garofalo-400g',
#    'imagen-del-producto': {'fileId': '6791b4f9663c82c00e7193f4',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/6791b4f9663c82c00e7193f4_LINGUINE%20GLUTEN%20FREE%20%E2%80%93%20400%20g.webp',
#     'alt': None},
#    'categories': '6660cae85768b4de8082734e'}},
#  {'id': '6791b481eb3438657773f229',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': None,
#   'lastUpdated': '2025-02-22T17:23:15.294Z',
#   'createdOn': '2025-01-23T03:16:17.341Z',
#   'isArchived': True,
#   'isDraft': True,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False,
#    'precio': '25000',
#    'descripcion': '<p id="">Ideal para ensaladas, sopas o como acompañamiento. &nbsp;Su versatilidad lo convierte en una opción perfecta para una alimentación saludable y variada.</p><p id="">\u200d</p>',
#    'gr-ml': 'Gramo a $50',
#    'name': 'BULGUR - 500gr',
#    'imagen-del-producto': {'fileId': '6791b3a4d110f44f285cf365',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/6791b3a4d110f44f285cf365_BULGUR%20%E2%80%93%20500%20G.webp',
#     'alt': None},
#    'slug': 'bulgur---500gr',
#    'categories': '6660cae85768b4de8082734e'}},
#  {'id': '6791b384eb3438657773019a',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': '2025-01-29T14:30:16.258Z',
#   'lastUpdated': '2025-01-23T13:54:29.692Z',
#   'createdOn': '2025-01-23T03:12:04.452Z',
#   'isArchived': False,
#   'isDraft': False,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False,
#    'precio': '26000',
#    'descripcion': '<p id="">Elaborados con trigo seleccionado y extruída en bronce. &nbsp;Son perfectos para platos horneados, ofreciendo una experiencia culinaria llena de sabor y textura.</p><p id="">\u200d</p>',
#    'gr-ml': 'Gramo a $104',
#    'name': 'CANNELLONI - 250g',
#    'imagen-del-producto': {'fileId': '6791b0d8d864a761c364f512',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/6791b0d8d864a761c364f512_CANNELLONI-250%20G.webp',
#     'alt': None},
#    'slug': 'cannelloni---250g',
#    'categories': '6660cae85768b4de8082734e'}},
#  {'id': '6791b0a0c8b0a28befaa4008',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': '2025-01-29T14:30:16.258Z',
#   'lastUpdated': '2025-01-23T13:56:07.112Z',
#   'createdOn': '2025-01-23T02:59:44.397Z',
#   'isArchived': False,
#   'isDraft': False,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False,
#    'precio': '18000',
#    'descripcion': '<p id="">Elaborados con trigo de alta calidad y extruída en bronce. Su forma única permite que las salsas se adhieran perfectamente, brindando una experiencia exquisita en cada bocado. Son ideales para acompañar tanto salsas ligeras como más intensas.</p>',
#    'gr-ml': 'Gramo a $36',
#    'name': 'FUSILLI LUNGHI X 500 gr Garofalo',
#    'imagen-del-producto': {'fileId': '6791b00530c2914856c40123',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/6791b00530c2914856c40123_FUSILLI%20LUNGHI%20X%20500%20gr%20Garofalo.webp',
#     'alt': None},
#    'slug': 'fusilli-lunghi-x-500-gr-garofalo',
#    'categories': '6660cae85768b4de8082734e'}},
#  {'id': '6791afcdc8b0a28befa98814',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': None,
#   'lastUpdated': '2025-01-24T17:51:36.262Z',
#   'createdOn': '2025-01-23T02:56:13.699Z',
#   'isArchived': True,
#   'isDraft': True,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False,
#    'precio': '18000',
#    'descripcion': '<p id="">Con alto contenido de proteína y completamente libre de gluten, es ideal para una alimentación saludable. Una opción perfecta para ensaladas, guarniciones o platos principales.</p><p id="">\u200d</p>',
#    'gr-ml': 'Gramo a $60',
#    'name': 'QUINOA -300gr',
#    'imagen-del-producto': {'fileId': '67919a7814669c355bb0043a',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/67919a7814669c355bb0043a_quinoa%20GAROGALO.webp',
#     'alt': None},
#    'slug': 'quinoa--300gr',
#    'categories': '6660cae85768b4de8082734e'}},
#  {'id': '6766d7b50e6dd15579ee58f4',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': '2025-05-05T23:32:45.915Z',
#   'lastUpdated': '2025-04-29T15:43:07.446Z',
#   'createdOn': '2024-12-21T14:59:01.698Z',
#   'isArchived': False,
#   'isDraft': False,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False,
#    'gr-ml': 'Gramo a $230',
#    'name': 'Pecorino Romano rallado 100G',
#    'descripcion': '<p id="">Pecorino Romano rallado.</p><p>100gr </p>',
#    'slug': 'pecorino-romano-rallado',
#    'categories': '6660ca3823741b8f165309d3',
#    'precio': '23000',
#    'imagen-del-producto': {'fileId': '6766d8c6eef1c83a03eeedd2',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/6766d8c6eef1c83a03eeedd2_QuesoRallado.webp',
#     'alt': None}}},
#  {'id': '6766d2ae7ba45de7384751bb',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': None,
#   'lastUpdated': '2025-04-15T17:42:55.920Z',
#   'createdOn': '2024-12-21T14:37:34.195Z',
#   'isArchived': True,
#   'isDraft': True,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False,
#    'precio': '26000',
#    'descripcion': '<p>Passata 700Gr Marca Cirio</p>',
#    'name': 'Passata 700g',
#    'imagen-del-producto': {'fileId': '6766d27aedb869e5117b971a',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/6766d27aedb869e5117b971a_passata700g.webp',
#     'alt': None},
#    'categories': '6660ca3823741b8f165309cb',
#    'slug': 'passata-700g',
#    'gr-ml': 'Gramo a $37.1'}},
#  {'id': '674e409d86bd5afb010a3800',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': '2025-05-05T23:32:45.915Z',
#   'lastUpdated': '2025-04-29T15:47:53.568Z',
#   'createdOn': '2024-12-02T23:19:57.749Z',
#   'isArchived': False,
#   'isDraft': False,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False,
#    'precio': '16000',
#    'descripcion': '<p>Queso Grana Padano Rayado 100 gramos</p>',
#    'name': 'Grana Padano Rallado 100G',
#    'categories': '6660ca3823741b8f165309d3',
#    'imagen-del-producto': {'fileId': '674e407faf6e38a3750117ff',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/674e407faf6e38a3750117ff_Grana%20Padano%20Pulverizado.webp',
#     'alt': None},
#    'slug': 'grana-padano-rallado-100g',
#    'gr-ml': 'Gramo a $160'}},
#  {'id': '6706f94d9341ac1661002cfa',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': '2025-04-03T20:47:13.491Z',
#   'lastUpdated': '2025-04-03T00:22:52.612Z',
#   'createdOn': '2024-10-09T21:44:45.650Z',
#   'isArchived': False,
#   'isDraft': False,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'gr-ml': 'Mililitro a $133',
#    'precio': '169000',
#    'bodega': 'Sior Sandro',
#    'name': 'Aspide + Prosecco ',
#    'slug': 'aspide-prosecco',
#    'descripcion': '<p id="">Combo Aperol Spritz</p><p>Prosecco + Aspide</p>',
#    'categoria': 'Vinos',
#    'categories': '6660ca3823741b8f165309d1',
#    'imagen-del-producto': {'fileId': '6706f8919ad68a2d446ca94f',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/6706f8919ad68a2d446ca94f_Producto%20Combo%20Aspide%20%2B%20Prosecco.webp',
#     'alt': None},
#    'productoreserva': False,
#    'descuento-off': False,
#    'precio-descuento': '212000'}},
#  {'id': '67034c482926b9ebb95dd93c',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': '2024-10-24T03:32:41.187Z',
#   'lastUpdated': '2024-10-07T02:49:44.787Z',
#   'createdOn': '2024-10-07T02:49:44.787Z',
#   'isArchived': False,
#   'isDraft': False,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'precio': '1371000',
#    'descripcion': '<p id=""><strong id="">GALLETAS BACIDIDAMA-ORLANDO GRONDONA</strong></p><p id="">Son elaborados con mantequilla pura, sin la adición de ninguna otras grasas ni conservantes, con una textura muy suave de avellana redonda y chocolate negro. La tradición de la familia Grondona elige la avellana tonda gentil de Piemonte, cuidadosamente seleccionada, comprada entera, tostada, pelada y molida justo antes de la masa para unir cada bocado con una experiencia intensa.</p><p id="">Presentación 90g.</p><p id=""><strong id="">MINI PANETTONE</strong></p><p id="">Todo el sabor del verdadero Panettone Clásico de Milan, relleno de frutos secos yuva pasa. </p><p id="">Presentación 100g.</p><p id=""><strong id="">ACEITE AROMATIZADO TRUFA NEGRA</strong></p><p id="">Un aceite obtenido con las aceitunas recolectadas en otoño y combinado con el sabor inconfundible de la trufa negra para desarrollar un producto único y exclusivo.</p><p id="">Presentación 100ml.</p><p id=""><strong id="">ACEITE EXTRA-VIRGENITALIANO-GUGLIELMI</strong></p><p id="">Aceite de Puglia a base de dos variedades autóctonas: Coratina y Ogliarola. Inconfundible por su sabory su intensidad al paladar.</p><p id="">Presentación 250ml.</p><p id=""><strong id="">VINAGRE BALSAMICO AÑEJO 3 AÑOS</strong></p><p id="">La combinación perfecta de características organolépticas que potencia la sensación de dulzor. Ideal para usar con quesos, tortillas, risotto y atún fresco. 3 años en barricas de madera fina. </p><p id="">Contenido de mosto: 60%-Presentación 250ml.</p><p id=""><strong id="">QUESO GRANA PADANO-CONSORZIO VIRGILIO</strong></p><p id="">Este queso tiene una maduración mínima de 12 meses. Los olores y aromas del Grana Padano DOP son la nata, el ensilado de maíz y la corteza de queso. Se perciben también sabores dulces, salados y especiados. </p><p id="">Presentación 200g.</p><p id=""><strong id="">LIMONCELLO 100CL</strong></p><p id="">Una exaltación del sabor, de los aromas y de los colores de los limones de Cerdeña. Intenso, vivo y agradable tanto helado suave como a temperatura ambiente combinado con tónica y champagne. El Limoncello es versátil y fresco, ideal para el aperitivo o como digestivo. Presentación 100ml.</p><p id=""><strong id="">QUESO PARMIGIANO REGGIANO-CONSORZIO VIRGILIO</strong></p><p id="">El Parmigiano Reggiano envejecido 22 meses tiene un sabor completo e intenso con toques de frutos secos y especias como la nuez moscada.</p><p id="">Presentación 300g.</p><p id=""><strong id="">SALSA DE TRUFA-JIMMY TARTUFI</strong></p><p id="">Esta salsa nace de la unión de setas y trufas, apreciada por su facilidad de uso y por su sabor característico. Además de ser un condimento perfecto para las pastas y los panini, la versatilidad de estas salsas las convierte en un componente creativo para acompañar cualquier plato o cualquier otra preparación culinaria.</p><p id="">Presentación 130g.</p><p id=""><strong id="">12 E MEZZO PRIMITIVO DEL SALENTO-VARVAGLIONE</strong></p><p id="">Una de las uvas más reconocidas de Puglia. De color rojo rubí con reflejos violáceos, presenta notas de frutos rojos y en boca presenta taninos medios, con frutos rojos frescos, notas de vainilla, especias, de un final medio largo.</p><p id=""><strong id="">BRUNELLO DI MONTALCINO DOCG-CAMIGLIANO</strong></p><p id="">Este vino a base de Sangiovese Grosso, descansa 24 meses mínimo en barrica y luego 12 en botella. Vino brillante, limpio. Color rubí intenso con reflejos granate. Es muy perfumado y aromático. Sus notas recuerdan a frutos del bosque como cerezas, moras y fresas y mermelada. Gracias a su paso por barrica también tiene notas que recuerdan a la vainilla y especias. En el paladar es un vino elegante y de gran cuerpo, seco y de larga persistencia. En conclusión, es un vino que refleja las características del terroir por su calidad y tipicidad. Promete una evolución interesante y prolongada.</p><p id=""><strong id="">UMBRIA ROSSO SAN GIORGIOIGT-LUNGAROTTI</strong></p><p id="" ...
#    'name': 'Ancheta Genova',
#    'slug': 'ancheta-genova-2',
#    'imagen-del-producto': {'fileId': '67034bad1a13aa2b11e57c3c',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/67034bad1a13aa2b11e57c3c__0000s_0000_Ancheta_09.png',
#     'alt': None},
#    'categories': '6660caffc04494865e3bce5f',
#    'productoreserva': False,
#    'descuento-off': False}},
#  {'id': '67034b5c08c894e25e3dd8a8',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': '2024-10-24T03:32:41.187Z',
#   'lastUpdated': '2024-10-07T02:45:48.921Z',
#   'createdOn': '2024-10-07T02:45:48.921Z',
#   'isArchived': False,
#   'isDraft': False,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'precio': '829000',
# ...
#    'notas-de-cata': 'Color amarillo pajizo con intensidad media y reflejos dorados, intensidad aromática con notas que recuerdan a flores silvestres, hierbas aromáticas, frutas maduras y miel, su acidez es fresca, de paladar persistente con estructura elegante y sedosa.',
#    'categoria': 'Vinos y licores',
#    'cepa-principal': 'Vermentino',
#    'region': 'Liguria',
#    'tipo': 'Blanco',
#    'item-id': '862',
#    'denominacion': 'DOC',
#    'slug': 'ampelos-vermentino-colli-di-luni-doc',
#    'categories': '66635db36d9753905f695788',
#    'imagen-del-producto': {'fileId': '6661c09e244d997e8c13597e',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/6661c09e244d997e8c13597e_AMPELOS-VERMENTINO-COLLI-DI-LUNI-DOC-100-1.jpg',
#     'alt': None},
#    'descuento': False,
#    'descuento-2x1': False,
#    'precio-descuento': '78750',
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False}},
#  {'id': '66615035a7cc81d396c8809f',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': None,
#   'lastUpdated': '2025-02-08T19:51:00.532Z',
#   'createdOn': '2024-06-06T05:59:17.766Z',
#   'isArchived': True,
#   'isDraft': False,
#   'fieldData': {'gr-ml': 'Mililitro a $151',
#    'ocasion': 'Cena entre amigos, Todas las ocasiones',
#    'temperatura-de-servicio': '10-13 °C. Descorchar al momento del servicio.',
#    'precio': '113000',
#    'maridaje-1': 'Ideal para acompañar carnes blancas\\, como pescados a la parrilla\\, pescados azules\\, también ideal con mariscos y platos cremosos como pastas y risottos.',
#    'maridaje-2': 'Pescado',
#    'pasillo': 'Vinos',
#    'bodega': 'Arrigoni',
#    'name': 'Vermentino "Vigna  Del Prefetto"',
#    'descripcion': '<p id="">ELABORACIÓN DEL VINO &nbsp; Vendimia manual, maceración de 12 horas con las pieles y vinificación en tanques de acero a temperatura controlada, Crianza en lías durante 6 meses.</p><p id="">VARIEDAD DE UVA Y ÁREA DE PRODUCCIÓN &nbsp; Vermentino 100%. Las uvas provienen de la zona de la Spezia en Cinque Terre. Las cepas tienen una edad promedio de 20 años y están plantadas a 150 mts sobre el nivel del mar. </p><p id="">GRADUACIÓN ALCOHÓLICA &nbsp; 13% vol.</p>',
#    'notas-de-cata': 'Color amarillo pajizo con reflejos dorados. En la nariz recuerda a notas de fruta como manzana verde\\, pera y duraznos\\, así como notas a vainilla y almendra.',
#    'categoria': 'Vinos y licores',
#    'cepa-principal': 'Vermentino',
#    'region': 'Liguria',
#    'tipo': 'Blanco',
#    'item-id': '861',
#    'denominacion': 'DOC',
#    'slug': 'vermentino-colli-di-luni-vigna-del-prefetto-doc',
#    'categories': '6660ca3823741b8f165309d1',
#    'imagen-del-producto': {'fileId': '6661c06058d19f9dcac08292',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/6661c06058d19f9dcac08292_VERMENTINO-COLLI-DI-LUNI-VIGNA-DEL-PREFETTO-DOC-100-1.webp',
#     'alt': None},
#    'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False}},
#  {'id': '666150354f742af9a75e85b3',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': '2025-03-12T23:27:56.606Z',
#   'lastUpdated': '2025-03-12T23:27:56.606Z',
#   'createdOn': '2024-06-06T05:59:17.385Z',
#   'isArchived': False,
#   'isDraft': False,
#   'fieldData': {'gr-ml': 'Mililitro a $205',
#    'ocasion': 'Cena entre amigos, Cena formal, Entre apasionados, Noche romantica, Todas las ocasiones',
#    'temperatura-de-servicio': '18-20 °C. Descorchar la botella una hora antes de servirlo.',
#    'precio': '154000',
#    'maridaje-1': 'Pasta y Pizza',
#    'maridaje-2': 'Sushi',
#    'pasillo': 'Vinos',
#    'bodega': 'Surrau',
#    'name': 'Cannonau "Sincaru"',
#    'descripcion': '<p id="">ELABORACIÓN DEL VINO &nbsp; Vendimia manual, la fermentación toma lugar en tanques de acero inoxidable a temperatura controlada, en contacto con las cáscaras. Añejamiento en tanques de cemento y toneles de roble.</p><p id="">VARIEDAD DE UVA Y ÁREA DE PRODUCCIÓN &nbsp; Cannonau 100%. Los viñedos están ubicados en el territorio de Arzachena, al norte de la isla. Para este vino, los viñedos se encuentran en colinas de 150 mts de altura, a pocos kilómetros del mar. Sus suelos principalmente compuestos por arena y granito y las plantaciones con orientación sur-este se benefician de los vientos marítimos que pasan por estas colinas. Las vides que dan origen a este vino son vides de +10 años.</p><p id="">GRADUACIÓN ALCOHÓLICA &nbsp; 14,5% vol.</p>',
#    'notas-de-cata': 'Color rojo rubí con reflejos violáceos. En la nariz se expresa con notas que recuerdan a los frutos negros como moras, ciruelas y cerezas, también notas que recuerdan al tabaco y al chocolate amargo. Taninos elegantes y sedosos. Final largo y persistente.',
#    'categoria': 'Vinos y licores',
#    'cepa-principal': 'Cannonau',
#    'region': 'Sardegna',
#    'tipo': 'Tinto',
#    'item-id': '856',
#    'denominacion': 'DOC',
#    'slug': 'sincaru-cannonau-di-sardegna-doc',
#    'categories': '6660ca3823741b8f165309d1',
#    'imagen-del-producto': {'fileId': '665fdbbb9cc6b21b4c717c38',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/665fdbbb9cc6b21b4c717c38_SINCARU-CANNONAU-DI-SARDEGNA-DOC-100-1.webp',
#     'alt': None},
#    'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False}},
#  {'id': '66615035a7cc81d396c88077',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': None,
#   'lastUpdated': '2025-02-07T04:30:44.636Z',
#   'createdOn': '2024-06-06T05:59:17.374Z',
#   'isArchived': True,
#   'isDraft': True,
#   'fieldData': {'gr-ml': 'Mililitro a $435',
#    'ocasion': 'Cena formal, Entre apasionados, Ocasión especial, Todas las ocasiones, Vinos importantes',
#    'temperatura-de-servicio': '18-20 °C. Se aconseja descorchar la botella una hora antes de servirlo.',
#    'precio': '163000',
#    'maridaje-1': 'Todas las comidas',
#    'maridaje-2': 'Carne',
#    'pasillo': 'Vinos',
#    'bodega': 'Villadoria',
#    'name': 'Barolo 375ml',
#    'descripcion': '<p id="">ELABORACIÓN DEL VINO &nbsp; La uva es despalillada y luego triturada delicadamente. La fermentación se realiza en depósitos de acero inoxidable a temperatura controlada (29 °C). La duración de la maceración varía dependiendo del año, de 20 a 30 días. El período de añejamiento requerido es de tres años después del año de cosecha; esto se lleva a cabo en barriles de roble de Eslavonia de 30 y 50 hl durante unos 30 meses; después de esto, termina el añejamiento en botella por algunos meses, para luego ser introducido al mercado.</p><p id="">VARIEDAD DE UVA Y ÁREA DE PRODUCCIÓN &nbsp; 100% Nebbiolo. Nebbiolo es un tipo uva de baya de color (negro) considerada como una de las variedades más valiosas, aptas para el envejecimiento de vinos de la más alta calidad. El término “nebbiolo” al parecer proviene de la palabra “nebbia” (niebla en español), aunque es incierto si este es para definir el aspecto de la uva, oscura pero deslucida (nebulosa), o si se debe a la tardía maduración de la uva, que a menudo conduce a la cosecha durante las neblinas otoñales. Las uvas de las que se obtiene este excelente Barolo provienen exclusivamente de viñedos situados en altas colinas en Serralunga d’Alba, todos propiedad de la familia Lanzavecchia. El suelo es de margas calcáreas originales de la época de Mioceno Langhiense. </p><p id="">GRADUACIÓN ALCOHÓLICA &nbsp; 14% vol.</p>',
#    'notas-de-cata': 'De un color rojo granada, con un aroma etéreo, agradable e intenso, que nos recuerda las violetas, rosas secas, cerezas, vainilla, tabaco, trufas y pimienta. Su sabor es seco, con cuerpo, robusto, austero pero suave y armonioso. Es sin duda uno de los vinos italianos más importantes y reconocidos en el mundo gracias a sus características únicas y su elegancia innata.',
#    'categoria': 'Vinos y licores',
#    'cepa-principal': 'Nebbiolo',
#    'region': 'Piemonte',
#    'tipo': 'Tinto',
#    'item-id': '854',
#    'denominacion': 'DOCG',
#    'slug': 'barolo-2012-docg---media-botella-375ml',
#    'categories': '6660ca3823741b8f165309d1',
#    'imagen-del-producto': {'fileId': '665fd395fb56850f5f344a42',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/665fd395fb56850f5f344a42_BAROLO-2012-DOCG-MEDIA-BOTELLA-375ML-100-1.webp',
#     'alt': None},
#    'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False}},
#  {'id': '66615035437397bdd5e69b3f',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': '2025-03-12T23:21:57.135Z',
#   'lastUpdated': '2025-03-12T23:21:57.135Z',
#   'createdOn': '2024-06-06T05:59:17.371Z',
#   'isArchived': False,
#   'isDraft': False,
#   'fieldData': {'gr-ml': 'Mililitro a $143',
#    'ocasion': 'Cena entre amigos, Para todos los días, Todas las ocasiones',
#    'temperatura-de-servicio': '18-20 °C.',
#    'precio': '69000',
#    'maridaje-1': 'Carne',
#    'maridaje-2': 'Mexicano',
#    'pasillo': 'Vinos',
#    'bodega': 'Surrau',
#    'name': 'Cannonau "Surrau”',
#    'descripcion': '<p id="">ELABORACIÓN DEL VINO &nbsp; Vendimia manual, la fermentación toma lugar en tanques de acero inoxidable a temperatura controlada, en contacto con las cáscaras. Añejamiento por unos meses en tanques de cemento y acero.</p><p id="">VARIEDAD DE UVA Y ÁREA DE PRODUCCIÓN &nbsp; Cannonau 100%. Los viñedos se encuentran en colinas de 150 mts de altura, a pocos kilómetros del mar. Sus suelos principalmente compuestos por arena y granito y las plantaciones con orientación sur-este se benefician de los vientos marítimos que pasan por estas colinas.</p><p id="">GRADUACIÓN ALCOHÓLICA &nbsp; 14% vol.</p>',
#    'notas-de-cata': 'Color rojo rubí con reflejos granate. En la nariz se expresa con notas que recuerdan a los frutos negros como moras, ciruelas y cerezas. Taninos elegantes y sedosos. Persistente y expresivo en el paladar.',
#    'categoria': 'Vinos y licores',
#    'cepa-principal': 'Cannonau',
#    'region': 'Sardegna',
#    'tipo': 'Tinto',
#    'item-id': '857',
#    'denominacion': 'DOC',
#    'slug': 'surrau-cannonau-di-sardegna-doc',
#    'categories': '66635db36d9753905f695788',
#    'imagen-del-producto': {'fileId': '665fde3030ad3afaf60d216e',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/665fde3030ad3afaf60d216e_SURRAU-CANNONAU-DI-SARDEGNA-DOC-100-1.webp',
#     'alt': None},
#    'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'precio-descuento': '109000',
#    'productoreserva': False,
#    'descuento-off': False}},
#  {'id': '6661503579739759bbd7e0b5',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': None,
#   'lastUpdated': '2025-02-22T02:05:45.164Z',
#   'createdOn': '2024-06-06T05:59:17.363Z',
#   'isArchived': True,
#   'isDraft': True,
#   'fieldData': {'gr-ml': 'Mililitro a $163',
#    'ocasion': 'Cena entre amigos, Cena formal, Entre apasionados, Para todos los días, Todas las ocasiones',
#    'temperatura-de-servicio': '17-18 °C.',
#    'precio': '122000',
#    'maridaje-1': 'Todas las comidas',
#    'maridaje-2': 'Carne',
#    'pasillo': 'Vinos',
#    'bodega': 'Arrigoni',
#    'name': 'Chianti Poggio Al Vento',
#    'descripcion': '<p id="">ELABORACIÓN DEL VINO &nbsp; Vendimia manual, la fermentación toma lugar en tanques de acero inoxidable. La maduración se lleva a cabo en barricas de roble durante 8 meses mínimo y posteriormente afinamiento en botellas durante 4 meses.</p><p id="">VARIEDAD DE UVA Y ÁREA DE PRODUCCIÓN &nbsp; Sangiovese 100%. Los viñedos se encuentran en la zona del Chianti Colli Senesi, cerca de la ciudad de Siena, en la región de Toscana. Las colinas que rodean la ciudad de siena representan las mejores zonas para la elaboración de Chianti. Una de estas colinas es conocida como San Gimignano.</p><p id="">GRADUACIÓN ALCOHÓLICA &nbsp; 13,5% vol.</p>',
#    'notas-de-cata': 'Color rojo rubí brillante. En la nariz es perfumado y delicado, con notas que evocan a frutos del bosque, principalmente cerezas, algunas notas florales como violetas, también algunas notas especiadas como tabaco. En el paladar es fresco, de cuerpo medio, acidez elegante y taninos medios.',
#    'categoria': 'Vinos y licores',
#    'cepa-principal': 'Sangiovese',
#    'region': 'Toscana',
#    'tipo': 'Tinto',
#    'item-id': '858',
#    'denominacion': 'DOCG',
#    'slug': 'poggio-al-vento-chianti-colli-senesi-docg',
#    'categories': '6660ca3823741b8f165309d1',
#    'imagen-del-producto': {'fileId': '665fdf4069d1fb5886008b84',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/665fdf4069d1fb5886008b84_POGGIO-AL-VENTO-CHIANTI-COLLI-SENESI-DOCG-100-1.webp',
#     'alt': None},
#    'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': True}},
#  {'id': '666150356ada726de4353e0e',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': None,
#   'lastUpdated': '2024-08-16T00:13:11.142Z',
#   'createdOn': '2024-06-06T05:59:17.360Z',
#   'isArchived': True,
#   'isDraft': False,
#   'fieldData': {'gr-ml': '264',
#    'ocasion': 'Cena formal, Entre apasionados, Ocasión especial, Todas las ocasiones, Vinos importantes',
#    'temperatura-de-servicio': '16-18 °C. Descorchar la botella media hora antes de servirlo.',
#    'precio': '198000',
#    'maridaje-1': 'Ideal para acompañar carnes rojas y de caza\\, como res y cordero. También es ideal con pastas y preparaciones estofadas. También es ideal para acompañar con charcutería y carnes curadas.',
#    'maridaje-2': 'Carne, Mexicano',
#    'pasillo': 'Vinos',
#    'bodega': 'Surrau',
#    'name': 'Cannonau Riserva "Sincaru"',
#    'descripcion': '<p>ELABORACIÓN DEL VINO   Vendimia manual, vinificación en tanques de acero a temperatura controlada. La fase de crianza en madera (roble eslavónico de tamaño medio) dura al menos 18 meses. Antes del embotellado se deja unos meses en pequeños tanques de hormigón, para luego trasladarlo a la botella donde permanecerá al menos seis meses.\\n\\nVARIEDAD DE UVA Y ÁREA DE PRODUCCIÓN   Cannonau 100%. Los viñedos están ubicados en el territorio de Arzachena, al norte de la isla. Para este vino, los viñedos se encuentran plantados en suelos de grava que le aporta balance y mineralidad. Sus suelos principalmente compuestos por arena y granito y las plantaciones con orientación sur-este se benefician de los vientos marítimos que pasan por estas colinas. Las vides que dan origen a este vino son vides de +10 años.\\n\\nGRADUACIÓN ALCOHÓLICA   14,5% vol.</p>',
#    'notas-de-cata': 'Color rojo rubí con reflejos granate. En la nariz tiene notas que recuerdan a las cerezas\\, fresas maduras\\, ciruelas y moras. Notas especiadas como pimienta y algún recuerdo de notas florales como rosas. En el paladar es elegante y persistente\\, taninos medios y suaves.',
#    'categoria': 'Vinos y licores',
#    'cepa-principal': 'Cannonau',
#    'region': 'Sardegna',
#    'tipo': 'Tinto',
#    'item-id': '855',
#    'denominacion': 'DOC',
#    'slug': 'sincaru-riserva-cannonau-di-sardegna-doc',
#    'categories': '6660ca3823741b8f165309d1',
#    'imagen-del-producto': {'fileId': '665fd6cd698fba26a4487f35',
#     'url': 'https://uploads-ssl.webflow.com/664d95581633c04b8a3808d3/665fd6cd698fba26a4487f35_SINCARU-RISERVA-CANNONAU-DI-SARDEGNA-DOC-100-1.jpg',
#     'alt': None},
#    'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False}}]

# %%
import numpy as np
import os
import re
import logging
import traceback
from typing import List
import requests

from qdrant_client.http.models import VectorParams, Distance
from qdrant_client import QdrantClient
from openai import OpenAI
from dotenv import load_dotenv
from fastapi import HTTPException


WEBFLOW_API_TOKEN = "026a04fef179155b6a04fbfd49e07c722e7621b91ad98961f6f298987c070180"
COLLECTION_ID = "6660d3a96fe3b376c162563e"
BASE_URL = f"https://api.webflow.com/v2/collections/{COLLECTION_ID}/items"

HEADERS = {
    "Authorization": f"Bearer {WEBFLOW_API_TOKEN}",
    "accept-version": "2.0.0"
}

def get_all_webflow_items():
    offset = 0
    limit = 100
    all_items = []

    while True:
        response = requests.get(
            BASE_URL,
            headers=HEADERS,
            params={"offset": offset, "limit": limit}
        )
        response.raise_for_status()
        data = response.json()
        items = data.get("items", [])

        all_items.extend(items)
        print(f"✅ Fetched {len(items)} items at offset {offset}")

        if len(items) < limit:
            break

        offset += limit

    return all_items

# Define top-level fields (outside fieldData)
top_fields = [
    "id",
    "lastPublished",
    "lastUpdated",
    "isArchived",
    "isDraft"
]

# Define selected fieldData fields
fielddata_fields = [
    "gr-ml",
    "ocasion",  # make sure spelling is consistent with Webflow — was 'ocasion' or 'occasion'?
    "precio",
    "maridaje-1",
    "maridaje-2",
    "pasillo",
    "bodega",
    "name",
    "descripcion",
    "notas-de-cata",
    "tipo",
    "slug",
    "descuento",
    "descuento-2x1",
    "descuento-3x2",
    "productoreserva",
    "descuento-off"
]

# Function to flatten and extract only desired fields
def extract_selected_fields(item):
    row = {}

    # Top-level fields
    for field in top_fields:
        row[field] = item.get(field)

    # From fieldData
    field_data = item.get("fieldData", {})
    for field in fielddata_fields:
        row[field] = field_data.get(field)
    
    # ✅ Extract image URL from 'imagen-del-producto'
    image_info = field_data.get("imagen-del-producto", {})
    if isinstance(image_info, dict):
        row["imagen_url"] = image_info.get("url")
    else:
        row["imagen_url"] = None

    return row


# Get and transform all items
items = get_all_webflow_items()
flattened_data = [extract_selected_fields(item) for item in items]

# Create the DataFrame
df = pd.DataFrame(flattened_data)

# Utility functions
def clean(text):
    if pd.isna(text): return ""
    return str(text).strip()

def strip_html(text):
    return BeautifulSoup(text, "html.parser").get_text(separator=" ", strip=True)


def get_openai_embedding(text: str) -> list:
    response = openai_client.embeddings.create(
        model="text-embedding-3-small",
        input=text
    )
    return response.data[0].embedding

# Connect to Qdrant
client = QdrantClient(host="vps.maestri.com.co", port=6333, https=False)
collection_name = "maestri_products"
embedding_size = 1536  # ✅ OpenAI embedding size is 1536

client.recreate_collection(
    collection_name=collection_name,
    vectors_config=VectorParams(size=embedding_size, distance=Distance.COSINE),
)

points = []

for _, row in df.iterrows():
    if pd.isna(row.get("name")) or pd.isna(row.get("precio")) or row.get("isArchived") is True or row.get("isDraft") is True or row.get("lastPublished") is None:
        continue

    product_name = clean(row.get("name"))
    bodega = clean(row.get("bodega"))
    tipo = clean(row.get("tipo"))
    maridaje1 = clean(row.get("maridaje-1"))
    maridaje2 = clean(row.get("maridaje-2"))
    maridaje = " y ".join([m for m in [maridaje1, maridaje2] if m])
    notas = clean(row.get("notas-de-cata"))
    descripcion = strip_html(clean(row.get("descripcion")))
    precio = clean(row.get("precio"))
    category = clean(row.get("pasillo"))
    gr_ml = clean(row.get("gr-ml"))
    ocasion = clean(row.get("ocasion"))
    slug = clean(row.get("slug"))
    url = f"https://maestri.com.co/products/{slug}" if slug else ""

    descuento = bool(row.get("descuento", False))
    descuento_2x1 = bool(row.get("descuento-2x1", False))
    descuento_3x2 = bool(row.get("descuento-3x2", False))
    productoreserva = bool(row.get("productoreserva", False))
    descuento_off = bool(row.get("descuento-off", False))
    url_imagen = row.get("imagen_url", "")
    if pd.isna(url_imagen):
        url_imagen = ""

    alternate_names = ""

    short_text = f"""Producto: {product_name}. Tipo: {tipo}. Bodega: {bodega}.
    Maridaje: {maridaje}. Notas: {notas}. Descripción: {descripcion}.
    También conocido como: {alternate_names}. Precio: {precio}. GR/ML: {gr_ml}. Ocasion: {ocasion}.
    """

    if not short_text.strip():
        continue

    # Get vector
    vector = get_openai_embedding(short_text)

    # Payload for Qdrant
    payload = {
        "product_name": product_name,
        "bodega": bodega,
        "tipo": tipo,
        "precio": precio,
        "notas": notas,
        "descripcion": descripcion,
        "maridaje": maridaje,
        "category": category,
        "gr_ml": gr_ml,
        "ocasion": ocasion,
        "url": url,
        "descuento": descuento,
        "descuento_2x1": descuento_2x1,
        "descuento_3x2": descuento_3x2,
        "productoreserva": productoreserva,
        "descuento_off": descuento_off,
        "alternate_names": alternate_names,
        "url_imagen": url_imagen
    }


    points.append(PointStruct(id=str(uuid.uuid4()), vector=vector, payload=payload))

# Insert into Qdrant
client.upsert(collection_name=collection_name, points=points)
print(f"✅ Inserted {len(points)} products into Qdrant collection: {collection_name}")
# Out:
# ✅ Fetched 100 items at offset 0
# ✅ Fetched 100 items at offset 100
# ✅ Fetched 100 items at offset 200
# ✅ Fetched 100 items at offset 300
# ✅ Fetched 20 items at offset 400
# C:\Users\dhernandez\AppData\Local\Temp\ipykernel_32868\4232199426.py:131: DeprecationWarning: `recreate_collection` method is deprecated and will be removed in the future. Use `collection_exists` to check collection existence and `create_collection` instead.
#   client.recreate_collection(
# ✅ Inserted 189 products into Qdrant collection: maestri_products

# %%
items
# Out:
# [{'id': '6823fa2dd9f312dbdbb2de73',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': '2025-05-14T02:04:29.094Z',
#   'lastUpdated': '2025-05-14T02:04:29.094Z',
#   'createdOn': '2025-05-14T02:04:29.094Z',
#   'isArchived': False,
#   'isDraft': False,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False,
#    'precio-descuento': '172000',
#    'gr-ml': 'Mililitro por $245,71',
#    'precio': '137600',
#    'pasillo': 'Vinos',
#    'bodega': 'Silvio Carta',
#    'name': 'Vermouth Blanco',
#    'descripcion': '<p>Esta inspirado en las recetas clásicas de principios del siglo XX. Sunombre y estética evocan la elegancia retro y el espíritu lúdico delos bares italianos de la década de 1920, elaborado coningredientes de origen sardo. Cuenta con Infusión de hierbasaromáticas, cáscaras de cítricos sardos, flores blancas y especiasligeras.Perfecto como aperitivo con hielo y una rodaja de limón, o encócteles como el Martini Bianco o el Bianco Spritz.La etiqueta y el nombre hacen referencia al año de nacimiento deSilvio Carta (1929), rindiendo homenaje al fundador y a la tradiciónde la casa.</p>',
#    'categoria': 'Vinos',
#    'peso-volumen': '700',
#    'slug': 'vermouth-blanco',
#    'categories': '6660ca3823741b8f165309d1',
#    'imagen-del-producto': {'fileId': '6823f941e0b84ef009f120d1',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/6823f941e0b84ef009f120d1_Vermouth%20Blanco.webp',
#     'alt': None}}},
#  {'id': '6823f83f37e7dd18f6e1d4ed',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': '2025-05-14T12:37:08.834Z',
#   'lastUpdated': '2025-05-14T12:37:08.834Z',
#   'createdOn': '2025-05-14T01:56:15.214Z',
#   'isArchived': False,
#   'isDraft': False,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False,
#    'gr-ml': 'Mililitro por $245,71',
#    'precio': '137600',
#    'pasillo': 'Vinos',
#    'bodega': 'Silvio Carta',
#    'name': 'Vermouth Rojo',
#    'descripcion': '<p>Se elabora a partir de Vernaccia di Oristano, un vino típico deCerdeña con crianza oxidativa, que aporta profundidad ysingularidad. Cuenta con botánicos autóctonos que incluye más de30 hierbas sardas, como el mirto, tomillo, hinojo salvaje y cítricoslocales.Estilo artesanal: La receta sigue un método tradicional con infusionesnaturales y maceraciones largas, sin aromas artificiales. Ideal paracócteles clásicos como el Negroni, Manhattan o Americano, perotambién se disfruta solo con hielo o como aperitivo.Intenso y elegante, dominado por notas de hierbas aromáticassardas, ajenjo, cítricos confitados, raíces y especias dulces comocanela y clavo</p>',
#    'categoria': 'Vinos',
#    'peso-volumen': '700 ml',
#    'categories': '6660ca3823741b8f165309d1',
#    'imagen-del-producto': {'fileId': '6823f75e9019171deb9eb296',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/6823f75e9019171deb9eb296_Vermouth-Rojo_1.webp',
#     'alt': None},
#    'slug': 'vermouth-rojo',
#    'precio-descuento': '172000'}},
#  {'id': '6823f71280a8d9de4f1a43f8',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': '2025-05-14T01:58:12.446Z',
#   'lastUpdated': '2025-05-14T01:58:12.446Z',
#   'createdOn': '2025-05-14T01:51:14.463Z',
#   'isArchived': False,
#   'isDraft': False,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False,
#    'precio-descuento': '212000',
#    'precio': '169600',
#    'pasillo': 'Vinos',
#    'name': 'Gin Pigskin',
#    'descripcion': '<p>Contiene botánicos locales como enebro sardo y una mezcla dehierbas mediterráneas seleccionadas, como mirto, hinojo y salvia.Posee un envejecimiento especial: Se madura brevemente enbarricas de castaño centenario que previamente contenían Vernacciadi Oristano, aportando complejidad.Cuenta con una graduación alcohólica: 40% vol, ideal para respetarel perfil London Dry sin perder su carácter local. “Pigskin” alude aljabalí salvaje de Cerdeña, un animal icónico de la isla, presente en laetiqueta y en el espíritu rústico y auténtico del gin.</p>',
#    'categoria': 'Vinos',
#    'categories': '6660ca3823741b8f165309d1',
#    'imagen-del-producto': {'fileId': '6823f6eb5d9db30ec9e5008f',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/6823f6eb5d9db30ec9e5008f_Gin%20Pigskin.webp',
#     'alt': None},
#    'slug': 'gin-pigskin',
#    'gr-ml': 'Mililitro por $302,85 ',
#    'peso-volumen': '700 ml',
#    'bodega': 'Silvio Carta'}},
#  {'id': '6823f68302f24dd9e4b9df4f',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': '2025-05-14T01:59:01.100Z',
#   'lastUpdated': '2025-05-14T01:59:01.100Z',
#   'createdOn': '2025-05-14T01:48:51.602Z',
#   'isArchived': False,
#   'isDraft': False,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False,
#    'precio-descuento': '22900',
#    'gr-ml': '$327,14 por ml',
#    'precio': '183200',
#    'name': 'Boigin Saffron',
#    'descripcion': '<p>Utiliza azafrán sardo de alta calidad, lo que le da un perfilaromático y cromático distintivo. Producido por SilvioCarta, una destilería histórica fundada en 1950, ubicadaen Baratili San Pietro, Cerdeña. Cuenta con un aGraduación alcohólica 40% vol, es un gin equilibrado paradestacar los botánicos sin perder intensidad.Es un London Dry Gin en espíritu, pero con un toqueinnovador gracias al uso de ingredientes locales, que lohacen único entre los gins artesanales italianos.</p>',
#    'categoria': 'Vinos',
#    'peso-volumen': '700 ml',
#    'categories': '6660ca3823741b8f165309d1',
#    'imagen-del-producto': {'fileId': '6823f5d73158646dd6226ec1',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/6823f5d73158646dd6226ec1_Boigin%20Saffron.webp',
#     'alt': None},
#    'slug': 'boigin-saffron',
#    'bodega': 'Silvio Carta'}},
#  {'id': '67e03ce522349689dfa5d528',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': '2025-05-05T23:32:45.915Z',
#   'lastUpdated': '2025-04-29T15:40:48.836Z',
#   'createdOn': '2025-03-23T16:55:01.562Z',
#   'isArchived': False,
#   'isDraft': False,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False,
#    'precio': '46000',
#    'pasillo': 'Quesos',
#    'name': 'Mascarpone 500gr',
#    'descripcion': '<p>El mascarpone, típicamente lombardo,se elabora respetando el proceso tradicional que realzasu cremosidad natural.Elaborado a partir de crema de leche, su sabor es delicado,con notas ligeramente dulces y mantecosas que lo hacenversátil para preparaciones tanto dulces como saladas.Ideal para postres como el clásico tiramisú, el mascarponetambién puede realzar platos salados como salsas cremosas,risottos o incluso ser utilizado como un deliciosoacompañamiento para frutas frescas o panes artesanales.</p>',
#    'categoria': 'Quesos',
#    'ciudad': 'Bogota',
#    'peso-volumen': '$67 por gramo',
#    'imagen-del-producto': {'fileId': '67e03c870e5925bb58b48787',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/67e03c870e5925bb58b48787_Mascarpone%20Virgilio.png',
#     'alt': None},
#    'categories': '6660ca3823741b8f165309d3',
#    'slug': 'mascarpone-500gr'}},
#  {'id': '67e03a6483dff41b3d812130',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': None,
#   'lastUpdated': '2025-04-07T22:59:15.695Z',
#   'createdOn': '2025-03-23T16:44:20.428Z',
#   'isArchived': True,
#   'isDraft': False,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False,
#    'precio-descuento': '270000',
#    'precio': '209000',
#    'name': 'Promo Torre Rosazza (3 vinos)',
#    'categoria': 'Vinos',
#    'imagen-del-producto': {'fileId': '67e03a5ada78afcaecd50cb7',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/67e03a5ada78afcaecd50cb7_Pieza%20Combo-20.jpg',
#     'alt': None},
#    'categories': '6660ca3823741b8f165309d1',
#    'slug': 'promo-torre-rosazza',
#    'bodega': 'Torre Rosazza',
#    'descripcion': '<p id="">Tras una cosecha a finales de agosto y un suave prensado, el proceso de vinificación se realiza en blanco separando inmediatamente los hollejos de los mostos y le sigue una fermentación alcohólica en depósitos de acero inoxidable a una temperatura controlada de 15-16 °C. El afinamiento se realiza sobre lías refinadas durante al menos 3 meses. Muy importante para el resultado final es la “ponca”: suelo margoso que se alterna con capas de arenisca, rico en minerales y pobre en materia orgánica. Este terreno es el que permite un desarrollo aromático en el bouquet de este vino.</p><p>\u200d</p><p>Pinot grigio + Traminer + Pinot Nero</p>',
#    'temperatura-de-servicio': '15-20C',
#    'tipo': 'Blanco',
#    'gr-ml': '$132 por ml'}},
#  {'id': '67bf19088c3f5d509954d232',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': '2025-03-21T04:51:14.899Z',
#   'lastUpdated': '2025-03-21T04:51:14.899Z',
#   'createdOn': '2025-02-26T13:37:12.400Z',
#   'isArchived': False,
#   'isDraft': False,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False,
#    'descripcion': '<p id="">De color rojo rubí brillante con sutiles reflejos granates, este Pinot Nero se caracteriza por su elegancia y complejidadaromática. </p>',
#    'precio': '59000',
#    'bodega': 'Torre Rosazza',
#    'name': 'Pinot Nero',
#    'categoria': 'Vinos',
#    'imagen-del-producto': {'fileId': '67bf180b8690788a35859739',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/67bf180b8690788a35859739_Pinot%20Nero%20-%20Torre%20Rosazza.png',
#     'alt': None},
#    'categories': '66635db36d9753905f695788',
#    'slug': 'pinot-nero',
#    'gr-ml': '$132 por ml',
#    'notas-de-cata': 'En nariz, ofrece notas intensas de frutos rojos como frambuesa, cereza y grosella, acompañadas notas florales de violeta y un delicado toque especiado de pimienta negra. En boca es equilibrada y sedoso, contaninos finos y unaacidez fresca que resalta su estructura. Su final es persistente y armonioso.\u200d',
#    'pasillo': 'Vinos',
#    'region': 'Friuli Grave',
#    'temperatura-de-servicio': '15-20°C',
#    'tipo': 'Tinto',
#    'precio-descuento': '99000'}},
#  {'id': '67bf17cce79602e51871cb68',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': '2025-03-21T04:51:56.411Z',
#   'lastUpdated': '2025-03-21T04:51:56.411Z',
#   'createdOn': '2025-02-26T13:31:56.706Z',
#   'isArchived': False,
#   'isDraft': False,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False,
#    'gr-ml': '$132 por ml',
#    'temperatura-de-servicio': '15-20°C',
#    'precio': '59000',
#    'pasillo': 'Vinos',
#    'bodega': 'Torre Rosazza',
#    'name': 'Traminer ',
#    'categoria': 'Vinos',
#    'imagen-del-producto': {'fileId': '67bf17443f298d9d76006591',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/67bf17443f298d9d76006591_Traminer%20-%20Torre%20Rosazza.png',
#     'alt': None},
#    'categories': '66635db36d9753905f695788',
#    'slug': 'traminer',
#    'cepa-principal': 'Traminer',
#    'descripcion': '<p id="">De color dorado brillante, este Traminer destaca por su expresividad aromática y elegancia</p>',
#    'notas-de-cata': 'En nariz, despliega un bouquet intenso con notas florales de jazmín, acompañado de frutas exóticas como lichi, maracuyá y cítricos maduros. Un delicado toque especiado de jengibre y pimienta blanca aporta complejidad. En boca es envolvente y armonioso, con una acidez vibrante que resalta su frescura.',
#    'peso-volumen': '750ml',
#    'region': 'Friuli Grave',
#    'tipo': 'Tinto',
#    'precio-descuento': '99000'}},
#  {'id': '67bbfa487f15dfc01f10d49a',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': '2025-03-12T23:40:37.558Z',
#   'lastUpdated': '2025-03-12T23:40:37.558Z',
#   'createdOn': '2025-02-24T04:49:12.465Z',
#   'isArchived': False,
#   'isDraft': False,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False,
#    'gr-ml': '$666.67 por ml',
#    'temperatura-de-servicio': '15-20°C',
#    'precio': '500000',
#    'pasillo': 'Vinos',
#    'bodega': 'Hofstatter',
#    'name': 'Barthenau Vigna',
#    'notas-de-cata': 'El aroma que recuerda a guindas y frambuesa se ve realzado por un delicado toque de vainilla y especias',
#    'categoria': 'Vinos',
#    'cepa-principal': 'Pinot Nero',
#    'region': 'Alto Adige',
#    'tipo': 'Tinto',
#    'denominacion': 'DOC',
#    'peso-volumen': '750',
#    'imagen-del-producto': {'fileId': '67bbf9ad3507c270ff17f918',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/67bbf9ad3507c270ff17f918_Barthenau%20Vigna.png',
#     'alt': None},
#    'categories': '6660ca3823741b8f165309d1',
#    'slug': 'barthenau-vigna'}},
#  {'id': '67bbf9825ce879aacaa08f34',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': '2025-03-12T23:40:16.691Z',
#   'lastUpdated': '2025-03-12T23:40:16.691Z',
#   'createdOn': '2025-02-24T04:45:54.714Z',
#   'isArchived': False,
#   'isDraft': False,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False,
#    'gr-ml': '$392 por ml',
#    'temperatura-de-servicio': '15-20°C',
#    'precio': '294000',
#    'pasillo': 'Vinos',
#    'bodega': 'Hofstatter',
#    'name': 'Mazon Reserva',
#    'descripcion': '<p id="">De color rojo rubí intenso con destellos granates. Presenta aromas complejos y elegantes de frutas rojas como cerezas y bayas negras, acompañadas denotas especiadas (pimienta negra, canela) y sutiles toques de vainilla, cacao y cuero,resultado de su crianza en roble. También aparecen matices terrosos y minerales que reflejan su terroir. Los taninos son finos, suaves e integrados.Los sabores de frutas rojas y especias se combinan con notas de tostado y madera, dejando un final largo,elegante y persistente.</p>',
#    'notas-de-cata': 'Los sabores de frutas rojas y especias se combinan con notas de tostado y madera, dejando un final largo, elegante y persistente',
#    'categoria': 'Vinos',
#    'cepa-principal': 'Pinot Nero',
#    'region': 'Alto Adige',
#    'tipo': 'Tinto',
#    'denominacion': 'DOC',
#    'peso-volumen': '750',
#    'imagen-del-producto': {'fileId': '67bbf9039964bb570dc2bdd5',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/67bbf9039964bb570dc2bdd5_Mazon%20pinot%20Nero.png',
#     'alt': None},
#    'categories': '6660ca3823741b8f165309d1',
#    'slug': 'mazon-reserva'}},
#  {'id': '67bbf8ae5a5c00b87042efb8',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': '2025-03-21T04:44:51.931Z',
#   'lastUpdated': '2025-03-21T04:44:51.931Z',
#   'createdOn': '2025-02-24T04:42:22.983Z',
#   'isArchived': False,
#   'isDraft': False,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False,
#    'gr-ml': '$182.6 por ml',
#    'temperatura-de-servicio': "15'20°C",
#    'precio': '99000',
#    'pasillo': 'Vinos',
#    'bodega': 'Hofstatter',
#    'name': 'Mezcan Vigneti',
#    'descripcion': '<p>De color rojo rubí brillante, con matices granates en los bordes, lo queindica su juventud y frescura. Presenta aromas delicados y complejos de frutas rojas,como fresas y cerezas, acompañados de notas florales y un ligero toque terroso. Con el tiempo en la copa, pueden aparecer matices de especias y hierbas que enriquecen superfil aromático. Es un vino elegante y equilibrado, con una acidez fresca que realza sucarácter frutal. Los taninos son suaves y bien integrados, ofreciendo una textura sedosa. El final es persistente, con sabores de frutas rojas y un toque mineral. el microclima único del altiplano de Mazón proporcionan las condiciones ideales paraproducir un Pinot Noir de calidad mundial.</p>',
#    'notas-de-cata': ' Presenta aromas complejos y elegantes de frutas rojas como cerezas y bayas negras, acompañadas de notas especiadas (pimienta negra, canela) y sutiles toques de vainilla, cacao y cuero, resultado de su crianza en roble',
#    'categoria': 'Vinos',
#    'cepa-principal': 'Pinot Nero',
#    'region': 'Trentino Alto Adige ',
#    'tipo': 'Tinto',
#    'denominacion': 'DOC',
#    'peso-volumen': '750',
#    'imagen-del-producto': {'fileId': '67bbf80c781f135c7f4216e3',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/67bbf80c781f135c7f4216e3_Mezcan%20Pinot%20Negro.png',
#     'alt': None},
#    'categories': '66635db36d9753905f695788',
#    'slug': 'mezcan-vigneti',
#    'precio-descuento': '137000'}},
#  {'id': '67bbf7466cbbed2183ea540d',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': '2025-03-12T23:39:59.448Z',
#   'lastUpdated': '2025-03-12T23:39:59.448Z',
#   'createdOn': '2025-02-24T04:36:22.072Z',
#   'isArchived': False,
#   'isDraft': False,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False,
#    'gr-ml': '$182.6 por ml',
#    'temperatura-de-servicio': '15-20°C',
#    'precio': '137000',
#    'pasillo': 'Vinos',
#    'bodega': 'Hofstatter',
#    'name': 'Merlot Alto Adige ',
#    'descripcion': '<p id="">De color rojo rubí profundo con reflejos púrpuras, este Merlot muestra una intensidad visual que anticipa su carácter robusto. Presenta aromas intensos y complejos que combinan frutas negras maduras, como ciruelas y moras, con toques decerezas oscuras. También se perciben notas especiadas de pimienta negra y clavo,junto con sutiles matices de cacao, tabaco, y un delicado fondo terroso. En boca esseco, con una textura aterciopelada y taninos bien estructurados pero suaves</p>',
#    'notas-de-cata': ' Presenta aromas intensos y complejos que combinan frutas negras maduras, como ciruelas y moras, con toques de cerezas oscuras',
#    'categoria': 'Vinos',
#    'region': 'Alto Adige',
#    'tipo': 'Tinto',
#    'denominacion': 'DOC',
#    'slug': 'merlot-alto-adige',
#    'imagen-del-producto': {'fileId': '67bbf68ccd6e05ec201ff856',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/67bbf68ccd6e05ec201ff856_Merlot%20Alto%20Adige.png',
#     'alt': None},
#    'categories': '6660ca3823741b8f165309d1'}},
#  {'id': '67b895502cb7b5f32a19a5ff',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': None,
#   'lastUpdated': '2025-02-25T16:57:41.421Z',
#   'createdOn': '2025-02-21T15:01:36.992Z',
#   'isArchived': False,
#   'isDraft': True,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False,
#    'precio': '0',
#    'name': 'Producto de testeo de flujo',
#    'imagen-del-producto': {'fileId': '67b89547c0d14e977f637527',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/67b89547c0d14e977f637527_WhatsApp%20Image%202024-10-27%20at%203.32.56%20PM.jpeg',
#     'alt': None},
#    'slug': 'producto-de-testeo-de-flujo',
#    'categories': '6660caffc04494865e3bce5f'}},
#  {'id': '67b6709183b9b745162ef761',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': '2025-03-12T23:39:02.315Z',
#   'lastUpdated': '2025-03-12T23:39:02.315Z',
#   'createdOn': '2025-02-20T00:00:17.224Z',
#   'isArchived': False,
#   'isDraft': False,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False,
#    'gr-ml': 'Mil a $1084',
#    'temperatura-de-servicio': '15 - 20C°',
#    'precio': '813000',
#    'pasillo': 'Vinos',
#    'bodega': 'Collazzi',
#    'name': 'Collazzi Ferro',
#    'descripcion': '<p>De color rojo rubí intenso con destellos violáceos, que revelan su juventud y frescura. Presentan aromas que despliegan una explosión de notas frutales,destacando cereza, frambuesa y ciruela madura, acompañadas de matices especiados de pimienta negra y un toque sutil de hierbas mediterráneas. La complejidad se ve enriquecida por notas de vainilla y tostados, resultado de su crianza en barrica. Es un vino con un final eterno y elegante.</p>',
#    'notas-de-cata': 'Presentan aromas que despliegan una explosión de notas frutales,destacando cereza, frambuesa y ciruela madura, acompañadas de matices especiados de pimienta negra y un toque sutil de hierbas mediterráneas',
#    'categoria': 'Vinos',
#    'cepa-principal': 'Petit Verdot',
#    'region': 'Toscana',
#    'denominacion': 'IGT',
#    'categories': '6660ca3823741b8f165309d1',
#    'imagen-del-producto': {'fileId': '67b66e73b6054b7759787afc',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/67b66e73b6054b7759787afc_Collazzi%20Ferro.png',
#     'alt': None},
#    'slug': 'collazzi-ferro',
#    'tipo': 'Tinto'}},
#  {'id': '67b66df9198f004787ea8553',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': '2025-03-12T23:35:53.471Z',
#   'lastUpdated': '2025-03-12T23:35:53.471Z',
#   'createdOn': '2025-02-19T23:49:13.401Z',
#   'isArchived': False,
#   'isDraft': False,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False,
#    'gr-ml': 'Mil a $470.6',
#    'temperatura-de-servicio': '15 y 20 grados C°',
#    'precio': '363000',
#    'pasillo': 'Vinos',
#    'name': 'Collazzi Rosso Toscana',
#    'descripcion': '<p>De color rojo rubí intenso. Presenta aromas frutales como cerezas,ciruelas y moras, acompañados de notas florales y especias. Con el tiempo, pueden surgir matices de vainilla y tostados, gracias a su crianza en barrica.Sabor: En boca es un vino bien equilibrado, con una acidez refrescante y taninos suaves, final ligeramente especiado y persistente. La madera está integrada, lo que aporta complejidad sin opacar la fruta</p>',
#    'categoria': 'Vinos',
#    'cepa-principal': 'Cabernet Sauvignon',
#    'region': 'Toscana',
#    'denominacion': 'IGT',
#    'imagen-del-producto': {'fileId': '67b66cbabf5b9788ab8a06b4',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/67b66cbabf5b9788ab8a06b4_Collazzi%20Rosso%20Toscana.png',
#     'alt': None},
#    'categories': '6660ca3823741b8f165309d1',
#    'slug': 'collazzi-rosso-toscana',
#    'tipo': 'Tinto'}},
#  {'id': '67b66c8f4cb91562c0953de5',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': '2025-03-12T23:35:38.943Z',
#   'lastUpdated': '2025-03-12T23:35:38.943Z',
#   'createdOn': '2025-02-19T23:43:11.566Z',
#   'isArchived': False,
#   'isDraft': False,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False,
#    'gr-ml': 'Mil a $200',
#    'precio': '150000',
#    'bodega': 'Collazzi',
#    'name': 'Collazzi Libertá Toscana',
#    'descripcion': '<p>Un vino que refleja la filosofía de libertad y creatividad de la finca Collazzi. De color rojo rubí profundo con reflejos violáceos. Presenta aromas intensos y complejos que combinan frutos rojos maduros como cerezas y ciruelas, con notas especiadas de vainilla, canela y un toque de regaliz, complementadas por un fondo decacao y tabaco. En boca, es redondo, sedoso y bien estructurado. Los taninos son suaves y elegantes, con una acidez equilibrada que aporta frescura.</p>',
#    'notas-de-cata': 'Presenta aromas intensos y complejos que combinan frutos rojos maduros como cerezas y ciruelas',
#    'categoria': 'Vinos',
#    'cepa-principal': 'Merlot',
#    'region': 'Toscana',
#    'denominacion': 'IGT',
#    'imagen-del-producto': {'fileId': '67b66b7c26e1abba88648838',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/67b66b7c26e1abba88648838_Collazzi%20Libert%C3%A1%20Toscana.png',
#     'alt': None},
#    'categories': '6660ca3823741b8f165309d1',
#    'slug': 'collazzi-liberta-toscana',
#    'tipo': 'Tinto'}},
#  {'id': '67b66b3ddeef0e34a9d7c842',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': '2025-03-21T04:50:37.300Z',
#   'lastUpdated': '2025-03-21T04:50:37.300Z',
#   'createdOn': '2025-02-19T23:37:33.156Z',
#   'isArchived': False,
#   'isDraft': False,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False,
#    'gr-ml': 'Mil a $182.7',
#    'precio': '99000',
#    'bodega': 'Collazzi',
#    'name': 'Collazzi Bastioni Chianti',
#    'descripcion': '<p>De color rojo rubí intenso con reflejos granate. Presenta aromas elegantes y complejos que combinan notas de frutas rojas frescas como cerezas y frambuesas, con toques de violetas, especias dulces, tabaco y un delicado matiz terroso. En boca, es estructurado y armonioso. Ofrece taninos firmes pero bien integrados, una acidez viva que aporta frescura y sabores persistentes de frutos rojos,hierbas mediterráneas y un sutil toque de roble tostado. Final largo y envolvente.</p>',
#    'categoria': 'Vinos',
#    'cepa-principal': 'Sangiovese',
#    'region': 'Chianti',
#    'denominacion': 'DOCG',
#    'imagen-del-producto': {'fileId': '67b66aaf9b1ef2ee60955604',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/67b66aaf9b1ef2ee60955604_Collazzi%20Bastioni%20Chianti.png',
#     'alt': None},
#    'categories': '66635db36d9753905f695788',
#    'slug': 'collazzi-bastioni-chianti',
#    'pasillo': 'Vinos',
#    'tipo': 'Tinto',
#    'precio-descuento': '137000'}},
#  {'id': '67b66a72bbf7fe75d958b4e2',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': None,
#   'lastUpdated': '2025-03-03T23:21:49.757Z',
#   'createdOn': '2025-02-19T23:34:10.483Z',
#   'isArchived': True,
#   'isDraft': True,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False,
#    'gr-ml': 'Mil a $182.7',
#    'precio': '137000',
#    'pasillo': 'Vinos',
#    'bodega': 'Collazzi',
#    'name': 'Collazzi Otto Muri',
#    'descripcion': '<p id="">De color amarillo limón brillante con reflejos dorados. Presenta aromas frescos con notas de flores blancas, frutas tropicales como piña y maracuyá, melocotón, pera madura, toque cítrico y un sutil toque mineral que evoca el suelo de origen. De cuerpo medio y bien equilibrado complementados por una acidez refrescante y un final persistente.</p>',
#    'notas-de-cata': 'Presenta aromas frescos con notas de flores blancas, frutas tropicales como piña y maracuyá, melocotón, pera madura, toque cítrico',
#    'categoria': 'Vinos',
#    'cepa-principal': 'Fiano',
#    'region': 'Toscana ',
#    'denominacion': 'IGT',
#    'peso-volumen': '750',
#    'imagen-del-producto': {'fileId': '67b6687dbbf7fe75d956dba7',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/67b6687dbbf7fe75d956dba7_Collazzi%20Otto%20Muri.png',
#     'alt': None},
#    'categories': '6660ca3823741b8f165309d1',
#    'slug': 'collazzi-otto-muri',
#    'tipo': 'Blanco'}},
#  {'id': '6791b94b28ed58d7ddf64fed',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': None,
#   'lastUpdated': '2025-01-26T02:12:07.971Z',
#   'createdOn': '2025-01-23T03:36:43.014Z',
#   'isArchived': True,
#   'isDraft': False,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False,
#    'precio': '14000',
#    'descripcion': '<p id="">Elaborados con trigo de alta calidad y extruídos en bronce, &nbsp;aseguran una excelente absorción de los condimentos, brindando una experiencia deliciosa y satisfactoria en cada bocado. Perfectos para acompañar salsas ricas o platos al horno.</p><p id="">\u200d</p>',
#    'gr-ml': 'Gramo a $28',
#    'name': 'RADIATORI - GAROFALO 500G',
#    'imagen-del-producto': {'fileId': '6791b945fb998feb3e7f62f8',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/6791b945fb998feb3e7f62f8_RADIATORI%20%E2%80%93%20500%20g.webp',
#     'alt': None},
#    'slug': 'radiatori---garofalo-500g',
#    'categories': '6660cae85768b4de8082734e'}},
#  {'id': '6791b8d92c849e7dae61e2d6',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': None,
#   'lastUpdated': '2025-02-22T17:16:13.566Z',
#   'createdOn': '2025-01-23T03:34:49.244Z',
#   'isArchived': True,
#   'isDraft': True,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False,
#    'precio': '80000',
#    'descripcion': '<p id=""><strong id="">DESCRIPCIÓN</strong> Línea exclusiva diseñada por Maestri Milano y la bodega familiar Assuli para Colombia, dos etiquetas que quieren representar a la fuerza y elegancia de los vinos de Sicilia.La familia Caruso, dueña de 120 hectáreas de tierra, desde hace varios años ha convertido su producción al método orgánico para valorar la autenticidad del<em id=""> terroir</em> local. El viñedo se encuentra en el lado occidental de Sicilia, en una zona reconocida por su centenaria historia vitivinícola: el sol, la luz, la alta mineralidad del suelo, los perfumes mediterráneos que trae el viento caracterizan vinos de gran personalidad. Trame D´oro</p>',
#    'gr-ml': '33',
#    'name': 'Producto de testeo de flujo',
#    'imagen-del-producto': {'fileId': '67ace0ecbac02ce79d45c36e',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/67ace0ecbac02ce79d45c36e_6661dfd49d136a73ff7dfd2f_caja1-1.jpeg',
#     'alt': None},
#    'slug': 'caja-de-madera-para-vinosss',
#    'categories': '66615043b65cd9e10cf74fa9',
#    'categoria': 'cajas',
#    'item-id': '66615043b65cd9e10cf74fa9',
#    'precio-descuento': '34000'}},
#  {'id': '6791b82351e5a36450294d76',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': '2025-01-29T14:30:16.258Z',
#   'lastUpdated': '2025-01-23T13:45:12.135Z',
#   'createdOn': '2025-01-23T03:31:47.719Z',
#   'isArchived': False,
#   'isDraft': False,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False,
#    'precio': '14000',
#    'descripcion': '<p>Su estructura única permite que las salsas se absorban de manera excepcional, ofreciendo una experiencia de sabor intensa. Perfectas para acompañar salsas espesas o platos al horno, brindan una textura firme y un sabor delicioso en cada bocado.</p>',
#    'gr-ml': 'Gramo a $28',
#    'name': 'CASARECCE - GAROFALO 500G',
#    'imagen-del-producto': {'fileId': '6791b7dd6a1db71ef14172b1',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/6791b7dd6a1db71ef14172b1_CASARECCE%20%E2%80%93%20500%20g.webp',
#     'alt': None},
#    'slug': 'casarecce---garofalo-500g',
#    'categories': '6660cae85768b4de8082734e'}},
#  {'id': '6791b7ab454bb2ea9c9d2cd7',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': '2025-01-29T14:30:16.258Z',
#   'lastUpdated': '2025-01-23T13:47:19.333Z',
#   'createdOn': '2025-01-23T03:29:47.441Z',
#   'isArchived': False,
#   'isDraft': False,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False,
#    'descripcion': '<p id="">Elaborados con trigo de alta calidad y extruídos en bronce. &nbsp;Son ideales para platos con salsas generosas o en preparaciones al horno, brindando una experiencia rica y satisfactoria en cada bocado.</p>',
#    'gr-ml': 'Gramo a $28',
#    'name': 'LUMACA RIGATA - GAROFALO 500G',
#    'slug': 'lumaca-rigata---garofalo-500g',
#    'imagen-del-producto': {'fileId': '6791b77383e9ee3f7ae003ff',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/6791b77383e9ee3f7ae003ff_Lumaca%20Rigata.webp',
#     'alt': None},
#    'precio': '14000',
#    'categories': '6660cae85768b4de8082734e'}},
#  {'id': '6791b71b793f67cbc54ad808',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': None,
#   'lastUpdated': '2025-02-08T12:07:03.939Z',
#   'createdOn': '2025-01-23T03:27:23.802Z',
#   'isArchived': True,
#   'isDraft': True,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False,
#    'precio': '14000',
#    'descripcion': '<p id="">Elaborados con trigo de alta calidad y extruídos en bronce. Son ideales para acompañar salsas densas o platos al horno, proporcionando una experiencia culinaria completa y deliciosa.</p>',
#    'gr-ml': 'Gramo a $28',
#    'name': 'MEZZE MANICHE RIGATE - GAROFALO 500G',
#    'imagen-del-producto': {'fileId': '6791b6d9ac4378cde99cd7c7',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/6791b6d9ac4378cde99cd7c7_MEZZE%20MANICHE%20RIGATE%20-%20GAROFALO%20500G.webp',
#     'alt': None},
#    'slug': 'mezze-maniche-rigate---garofalo-500g',
#    'categories': '6660cae85768b4de8082734e'}},
#  {'id': '6791b6b7218eed54a4aadd91',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': '2025-01-29T14:30:16.258Z',
#   'lastUpdated': '2025-01-23T13:51:26.316Z',
#   'createdOn': '2025-01-23T03:25:43.779Z',
#   'isArchived': False,
#   'isDraft': False,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False,
#    'precio': '18000',
#    'descripcion': '<p id="">Elaborados con trigo de alta calidad y extruídos en bronce, son ideales para ser rellenos con ingredientes exquisitos y disfrutar en platos gratinados o al horno. </p><p id="">\u200d</p>',
#    'gr-ml': 'Gramo a $36',
#    'name': 'CONCHIGLIONI - GAROFALO 500G',
#    'imagen-del-producto': {'fileId': '6791b65a2c849e7dae5f9099',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/6791b65a2c849e7dae5f9099_CONCHIGLIONI%20%E2%80%93%20500%20G.webp',
#     'alt': None},
#    'slug': 'conchiglioni---garofalo-500g',
#    'categories': '6660cae85768b4de8082734e'}},
#  {'id': '6791b62dac4378cde99c27f6',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': None,
#   'lastUpdated': '2025-03-26T15:04:30.631Z',
#   'createdOn': '2025-01-23T03:23:25.062Z',
#   'isArchived': True,
#   'isDraft': True,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False,
#    'precio': '21000',
#    'descripcion': '<p id="">Los Linguine Gluten Free Garofalo son elaborados con una mezcla de harinas seleccionadas para ofrecer una textura firme y una excelente capacidad de absorción de salsas. Perfectos para quienes siguen una dieta sin gluten, mantienen la tradición italiana de calidad y sabor en cada plato.</p><p id="">\u200d</p>',
#    'gr-ml': 'Gramo a $52',
#    'name': 'LINGUINE GLUTEN FREE - GAROFALO 400G',
#    'slug': 'linguine-gluten-free---garofalo-400g',
#    'imagen-del-producto': {'fileId': '6791b4f9663c82c00e7193f4',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/6791b4f9663c82c00e7193f4_LINGUINE%20GLUTEN%20FREE%20%E2%80%93%20400%20g.webp',
#     'alt': None},
#    'categories': '6660cae85768b4de8082734e'}},
#  {'id': '6791b481eb3438657773f229',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': None,
#   'lastUpdated': '2025-02-22T17:23:15.294Z',
#   'createdOn': '2025-01-23T03:16:17.341Z',
#   'isArchived': True,
#   'isDraft': True,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False,
#    'precio': '25000',
#    'descripcion': '<p id="">Ideal para ensaladas, sopas o como acompañamiento. &nbsp;Su versatilidad lo convierte en una opción perfecta para una alimentación saludable y variada.</p><p id="">\u200d</p>',
#    'gr-ml': 'Gramo a $50',
#    'name': 'BULGUR - 500gr',
#    'imagen-del-producto': {'fileId': '6791b3a4d110f44f285cf365',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/6791b3a4d110f44f285cf365_BULGUR%20%E2%80%93%20500%20G.webp',
#     'alt': None},
#    'slug': 'bulgur---500gr',
#    'categories': '6660cae85768b4de8082734e'}},
#  {'id': '6791b384eb3438657773019a',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': '2025-01-29T14:30:16.258Z',
#   'lastUpdated': '2025-01-23T13:54:29.692Z',
#   'createdOn': '2025-01-23T03:12:04.452Z',
#   'isArchived': False,
#   'isDraft': False,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False,
#    'precio': '26000',
#    'descripcion': '<p id="">Elaborados con trigo seleccionado y extruída en bronce. &nbsp;Son perfectos para platos horneados, ofreciendo una experiencia culinaria llena de sabor y textura.</p><p id="">\u200d</p>',
#    'gr-ml': 'Gramo a $104',
#    'name': 'CANNELLONI - 250g',
#    'imagen-del-producto': {'fileId': '6791b0d8d864a761c364f512',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/6791b0d8d864a761c364f512_CANNELLONI-250%20G.webp',
#     'alt': None},
#    'slug': 'cannelloni---250g',
#    'categories': '6660cae85768b4de8082734e'}},
#  {'id': '6791b0a0c8b0a28befaa4008',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': '2025-01-29T14:30:16.258Z',
#   'lastUpdated': '2025-01-23T13:56:07.112Z',
#   'createdOn': '2025-01-23T02:59:44.397Z',
#   'isArchived': False,
#   'isDraft': False,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False,
#    'precio': '18000',
#    'descripcion': '<p id="">Elaborados con trigo de alta calidad y extruída en bronce. Su forma única permite que las salsas se adhieran perfectamente, brindando una experiencia exquisita en cada bocado. Son ideales para acompañar tanto salsas ligeras como más intensas.</p>',
#    'gr-ml': 'Gramo a $36',
#    'name': 'FUSILLI LUNGHI X 500 gr Garofalo',
#    'imagen-del-producto': {'fileId': '6791b00530c2914856c40123',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/6791b00530c2914856c40123_FUSILLI%20LUNGHI%20X%20500%20gr%20Garofalo.webp',
#     'alt': None},
#    'slug': 'fusilli-lunghi-x-500-gr-garofalo',
#    'categories': '6660cae85768b4de8082734e'}},
#  {'id': '6791afcdc8b0a28befa98814',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': None,
#   'lastUpdated': '2025-01-24T17:51:36.262Z',
#   'createdOn': '2025-01-23T02:56:13.699Z',
#   'isArchived': True,
#   'isDraft': True,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False,
#    'precio': '18000',
#    'descripcion': '<p id="">Con alto contenido de proteína y completamente libre de gluten, es ideal para una alimentación saludable. Una opción perfecta para ensaladas, guarniciones o platos principales.</p><p id="">\u200d</p>',
#    'gr-ml': 'Gramo a $60',
#    'name': 'QUINOA -300gr',
#    'imagen-del-producto': {'fileId': '67919a7814669c355bb0043a',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/67919a7814669c355bb0043a_quinoa%20GAROGALO.webp',
#     'alt': None},
#    'slug': 'quinoa--300gr',
#    'categories': '6660cae85768b4de8082734e'}},
#  {'id': '6766d7b50e6dd15579ee58f4',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': '2025-05-05T23:32:45.915Z',
#   'lastUpdated': '2025-04-29T15:43:07.446Z',
#   'createdOn': '2024-12-21T14:59:01.698Z',
#   'isArchived': False,
#   'isDraft': False,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False,
#    'gr-ml': 'Gramo a $230',
#    'name': 'Pecorino Romano rallado 100G',
#    'descripcion': '<p id="">Pecorino Romano rallado.</p><p>100gr </p>',
#    'slug': 'pecorino-romano-rallado',
#    'categories': '6660ca3823741b8f165309d3',
#    'precio': '23000',
#    'imagen-del-producto': {'fileId': '6766d8c6eef1c83a03eeedd2',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/6766d8c6eef1c83a03eeedd2_QuesoRallado.webp',
#     'alt': None}}},
#  {'id': '6766d2ae7ba45de7384751bb',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': None,
#   'lastUpdated': '2025-04-15T17:42:55.920Z',
#   'createdOn': '2024-12-21T14:37:34.195Z',
#   'isArchived': True,
#   'isDraft': True,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False,
#    'precio': '26000',
#    'descripcion': '<p>Passata 700Gr Marca Cirio</p>',
#    'name': 'Passata 700g',
#    'imagen-del-producto': {'fileId': '6766d27aedb869e5117b971a',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/6766d27aedb869e5117b971a_passata700g.webp',
#     'alt': None},
#    'categories': '6660ca3823741b8f165309cb',
#    'slug': 'passata-700g',
#    'gr-ml': 'Gramo a $37.1'}},
#  {'id': '674e409d86bd5afb010a3800',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': '2025-05-05T23:32:45.915Z',
#   'lastUpdated': '2025-04-29T15:47:53.568Z',
#   'createdOn': '2024-12-02T23:19:57.749Z',
#   'isArchived': False,
#   'isDraft': False,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False,
#    'precio': '16000',
#    'descripcion': '<p>Queso Grana Padano Rayado 100 gramos</p>',
#    'name': 'Grana Padano Rallado 100G',
#    'categories': '6660ca3823741b8f165309d3',
#    'imagen-del-producto': {'fileId': '674e407faf6e38a3750117ff',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/674e407faf6e38a3750117ff_Grana%20Padano%20Pulverizado.webp',
#     'alt': None},
#    'slug': 'grana-padano-rallado-100g',
#    'gr-ml': 'Gramo a $160'}},
#  {'id': '6706f94d9341ac1661002cfa',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': '2025-04-03T20:47:13.491Z',
#   'lastUpdated': '2025-04-03T00:22:52.612Z',
#   'createdOn': '2024-10-09T21:44:45.650Z',
#   'isArchived': False,
#   'isDraft': False,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'gr-ml': 'Mililitro a $133',
#    'precio': '169000',
#    'bodega': 'Sior Sandro',
#    'name': 'Aspide + Prosecco ',
#    'slug': 'aspide-prosecco',
#    'descripcion': '<p id="">Combo Aperol Spritz</p><p>Prosecco + Aspide</p>',
#    'categoria': 'Vinos',
#    'categories': '6660ca3823741b8f165309d1',
#    'imagen-del-producto': {'fileId': '6706f8919ad68a2d446ca94f',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/6706f8919ad68a2d446ca94f_Producto%20Combo%20Aspide%20%2B%20Prosecco.webp',
#     'alt': None},
#    'productoreserva': False,
#    'descuento-off': False,
#    'precio-descuento': '212000'}},
#  {'id': '67034c482926b9ebb95dd93c',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': '2024-10-24T03:32:41.187Z',
#   'lastUpdated': '2024-10-07T02:49:44.787Z',
#   'createdOn': '2024-10-07T02:49:44.787Z',
#   'isArchived': False,
#   'isDraft': False,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'precio': '1371000',
#    'descripcion': '<p id=""><strong id="">GALLETAS BACIDIDAMA-ORLANDO GRONDONA</strong></p><p id="">Son elaborados con mantequilla pura, sin la adición de ninguna otras grasas ni conservantes, con una textura muy suave de avellana redonda y chocolate negro. La tradición de la familia Grondona elige la avellana tonda gentil de Piemonte, cuidadosamente seleccionada, comprada entera, tostada, pelada y molida justo antes de la masa para unir cada bocado con una experiencia intensa.</p><p id="">Presentación 90g.</p><p id=""><strong id="">MINI PANETTONE</strong></p><p id="">Todo el sabor del verdadero Panettone Clásico de Milan, relleno de frutos secos yuva pasa. </p><p id="">Presentación 100g.</p><p id=""><strong id="">ACEITE AROMATIZADO TRUFA NEGRA</strong></p><p id="">Un aceite obtenido con las aceitunas recolectadas en otoño y combinado con el sabor inconfundible de la trufa negra para desarrollar un producto único y exclusivo.</p><p id="">Presentación 100ml.</p><p id=""><strong id="">ACEITE EXTRA-VIRGENITALIANO-GUGLIELMI</strong></p><p id="">Aceite de Puglia a base de dos variedades autóctonas: Coratina y Ogliarola. Inconfundible por su sabory su intensidad al paladar.</p><p id="">Presentación 250ml.</p><p id=""><strong id="">VINAGRE BALSAMICO AÑEJO 3 AÑOS</strong></p><p id="">La combinación perfecta de características organolépticas que potencia la sensación de dulzor. Ideal para usar con quesos, tortillas, risotto y atún fresco. 3 años en barricas de madera fina. </p><p id="">Contenido de mosto: 60%-Presentación 250ml.</p><p id=""><strong id="">QUESO GRANA PADANO-CONSORZIO VIRGILIO</strong></p><p id="">Este queso tiene una maduración mínima de 12 meses. Los olores y aromas del Grana Padano DOP son la nata, el ensilado de maíz y la corteza de queso. Se perciben también sabores dulces, salados y especiados. </p><p id="">Presentación 200g.</p><p id=""><strong id="">LIMONCELLO 100CL</strong></p><p id="">Una exaltación del sabor, de los aromas y de los colores de los limones de Cerdeña. Intenso, vivo y agradable tanto helado suave como a temperatura ambiente combinado con tónica y champagne. El Limoncello es versátil y fresco, ideal para el aperitivo o como digestivo. Presentación 100ml.</p><p id=""><strong id="">QUESO PARMIGIANO REGGIANO-CONSORZIO VIRGILIO</strong></p><p id="">El Parmigiano Reggiano envejecido 22 meses tiene un sabor completo e intenso con toques de frutos secos y especias como la nuez moscada.</p><p id="">Presentación 300g.</p><p id=""><strong id="">SALSA DE TRUFA-JIMMY TARTUFI</strong></p><p id="">Esta salsa nace de la unión de setas y trufas, apreciada por su facilidad de uso y por su sabor característico. Además de ser un condimento perfecto para las pastas y los panini, la versatilidad de estas salsas las convierte en un componente creativo para acompañar cualquier plato o cualquier otra preparación culinaria.</p><p id="">Presentación 130g.</p><p id=""><strong id="">12 E MEZZO PRIMITIVO DEL SALENTO-VARVAGLIONE</strong></p><p id="">Una de las uvas más reconocidas de Puglia. De color rojo rubí con reflejos violáceos, presenta notas de frutos rojos y en boca presenta taninos medios, con frutos rojos frescos, notas de vainilla, especias, de un final medio largo.</p><p id=""><strong id="">BRUNELLO DI MONTALCINO DOCG-CAMIGLIANO</strong></p><p id="">Este vino a base de Sangiovese Grosso, descansa 24 meses mínimo en barrica y luego 12 en botella. Vino brillante, limpio. Color rubí intenso con reflejos granate. Es muy perfumado y aromático. Sus notas recuerdan a frutos del bosque como cerezas, moras y fresas y mermelada. Gracias a su paso por barrica también tiene notas que recuerdan a la vainilla y especias. En el paladar es un vino elegante y de gran cuerpo, seco y de larga persistencia. En conclusión, es un vino que refleja las características del terroir por su calidad y tipicidad. Promete una evolución interesante y prolongada.</p><p id=""><strong id="">UMBRIA ROSSO SAN GIORGIOIGT-LUNGAROTTI</strong></p><p id="" ...
#    'name': 'Ancheta Genova',
#    'slug': 'ancheta-genova-2',
#    'imagen-del-producto': {'fileId': '67034bad1a13aa2b11e57c3c',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/67034bad1a13aa2b11e57c3c__0000s_0000_Ancheta_09.png',
#     'alt': None},
#    'categories': '6660caffc04494865e3bce5f',
#    'productoreserva': False,
#    'descuento-off': False}},
#  {'id': '67034b5c08c894e25e3dd8a8',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': '2024-10-24T03:32:41.187Z',
#   'lastUpdated': '2024-10-07T02:45:48.921Z',
#   'createdOn': '2024-10-07T02:45:48.921Z',
#   'isArchived': False,
#   'isDraft': False,
#   'fieldData': {'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'precio': '829000',
# ...
#    'notas-de-cata': 'Color amarillo pajizo con intensidad media y reflejos dorados, intensidad aromática con notas que recuerdan a flores silvestres, hierbas aromáticas, frutas maduras y miel, su acidez es fresca, de paladar persistente con estructura elegante y sedosa.',
#    'categoria': 'Vinos y licores',
#    'cepa-principal': 'Vermentino',
#    'region': 'Liguria',
#    'tipo': 'Blanco',
#    'item-id': '862',
#    'denominacion': 'DOC',
#    'slug': 'ampelos-vermentino-colli-di-luni-doc',
#    'categories': '66635db36d9753905f695788',
#    'imagen-del-producto': {'fileId': '6661c09e244d997e8c13597e',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/6661c09e244d997e8c13597e_AMPELOS-VERMENTINO-COLLI-DI-LUNI-DOC-100-1.jpg',
#     'alt': None},
#    'descuento': False,
#    'descuento-2x1': False,
#    'precio-descuento': '78750',
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False}},
#  {'id': '66615035a7cc81d396c8809f',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': None,
#   'lastUpdated': '2025-02-08T19:51:00.532Z',
#   'createdOn': '2024-06-06T05:59:17.766Z',
#   'isArchived': True,
#   'isDraft': False,
#   'fieldData': {'gr-ml': 'Mililitro a $151',
#    'ocasion': 'Cena entre amigos, Todas las ocasiones',
#    'temperatura-de-servicio': '10-13 °C. Descorchar al momento del servicio.',
#    'precio': '113000',
#    'maridaje-1': 'Ideal para acompañar carnes blancas\\, como pescados a la parrilla\\, pescados azules\\, también ideal con mariscos y platos cremosos como pastas y risottos.',
#    'maridaje-2': 'Pescado',
#    'pasillo': 'Vinos',
#    'bodega': 'Arrigoni',
#    'name': 'Vermentino "Vigna  Del Prefetto"',
#    'descripcion': '<p id="">ELABORACIÓN DEL VINO &nbsp; Vendimia manual, maceración de 12 horas con las pieles y vinificación en tanques de acero a temperatura controlada, Crianza en lías durante 6 meses.</p><p id="">VARIEDAD DE UVA Y ÁREA DE PRODUCCIÓN &nbsp; Vermentino 100%. Las uvas provienen de la zona de la Spezia en Cinque Terre. Las cepas tienen una edad promedio de 20 años y están plantadas a 150 mts sobre el nivel del mar. </p><p id="">GRADUACIÓN ALCOHÓLICA &nbsp; 13% vol.</p>',
#    'notas-de-cata': 'Color amarillo pajizo con reflejos dorados. En la nariz recuerda a notas de fruta como manzana verde\\, pera y duraznos\\, así como notas a vainilla y almendra.',
#    'categoria': 'Vinos y licores',
#    'cepa-principal': 'Vermentino',
#    'region': 'Liguria',
#    'tipo': 'Blanco',
#    'item-id': '861',
#    'denominacion': 'DOC',
#    'slug': 'vermentino-colli-di-luni-vigna-del-prefetto-doc',
#    'categories': '6660ca3823741b8f165309d1',
#    'imagen-del-producto': {'fileId': '6661c06058d19f9dcac08292',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/6661c06058d19f9dcac08292_VERMENTINO-COLLI-DI-LUNI-VIGNA-DEL-PREFETTO-DOC-100-1.webp',
#     'alt': None},
#    'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False}},
#  {'id': '666150354f742af9a75e85b3',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': '2025-03-12T23:27:56.606Z',
#   'lastUpdated': '2025-03-12T23:27:56.606Z',
#   'createdOn': '2024-06-06T05:59:17.385Z',
#   'isArchived': False,
#   'isDraft': False,
#   'fieldData': {'gr-ml': 'Mililitro a $205',
#    'ocasion': 'Cena entre amigos, Cena formal, Entre apasionados, Noche romantica, Todas las ocasiones',
#    'temperatura-de-servicio': '18-20 °C. Descorchar la botella una hora antes de servirlo.',
#    'precio': '154000',
#    'maridaje-1': 'Pasta y Pizza',
#    'maridaje-2': 'Sushi',
#    'pasillo': 'Vinos',
#    'bodega': 'Surrau',
#    'name': 'Cannonau "Sincaru"',
#    'descripcion': '<p id="">ELABORACIÓN DEL VINO &nbsp; Vendimia manual, la fermentación toma lugar en tanques de acero inoxidable a temperatura controlada, en contacto con las cáscaras. Añejamiento en tanques de cemento y toneles de roble.</p><p id="">VARIEDAD DE UVA Y ÁREA DE PRODUCCIÓN &nbsp; Cannonau 100%. Los viñedos están ubicados en el territorio de Arzachena, al norte de la isla. Para este vino, los viñedos se encuentran en colinas de 150 mts de altura, a pocos kilómetros del mar. Sus suelos principalmente compuestos por arena y granito y las plantaciones con orientación sur-este se benefician de los vientos marítimos que pasan por estas colinas. Las vides que dan origen a este vino son vides de +10 años.</p><p id="">GRADUACIÓN ALCOHÓLICA &nbsp; 14,5% vol.</p>',
#    'notas-de-cata': 'Color rojo rubí con reflejos violáceos. En la nariz se expresa con notas que recuerdan a los frutos negros como moras, ciruelas y cerezas, también notas que recuerdan al tabaco y al chocolate amargo. Taninos elegantes y sedosos. Final largo y persistente.',
#    'categoria': 'Vinos y licores',
#    'cepa-principal': 'Cannonau',
#    'region': 'Sardegna',
#    'tipo': 'Tinto',
#    'item-id': '856',
#    'denominacion': 'DOC',
#    'slug': 'sincaru-cannonau-di-sardegna-doc',
#    'categories': '6660ca3823741b8f165309d1',
#    'imagen-del-producto': {'fileId': '665fdbbb9cc6b21b4c717c38',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/665fdbbb9cc6b21b4c717c38_SINCARU-CANNONAU-DI-SARDEGNA-DOC-100-1.webp',
#     'alt': None},
#    'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False}},
#  {'id': '66615035a7cc81d396c88077',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': None,
#   'lastUpdated': '2025-02-07T04:30:44.636Z',
#   'createdOn': '2024-06-06T05:59:17.374Z',
#   'isArchived': True,
#   'isDraft': True,
#   'fieldData': {'gr-ml': 'Mililitro a $435',
#    'ocasion': 'Cena formal, Entre apasionados, Ocasión especial, Todas las ocasiones, Vinos importantes',
#    'temperatura-de-servicio': '18-20 °C. Se aconseja descorchar la botella una hora antes de servirlo.',
#    'precio': '163000',
#    'maridaje-1': 'Todas las comidas',
#    'maridaje-2': 'Carne',
#    'pasillo': 'Vinos',
#    'bodega': 'Villadoria',
#    'name': 'Barolo 375ml',
#    'descripcion': '<p id="">ELABORACIÓN DEL VINO &nbsp; La uva es despalillada y luego triturada delicadamente. La fermentación se realiza en depósitos de acero inoxidable a temperatura controlada (29 °C). La duración de la maceración varía dependiendo del año, de 20 a 30 días. El período de añejamiento requerido es de tres años después del año de cosecha; esto se lleva a cabo en barriles de roble de Eslavonia de 30 y 50 hl durante unos 30 meses; después de esto, termina el añejamiento en botella por algunos meses, para luego ser introducido al mercado.</p><p id="">VARIEDAD DE UVA Y ÁREA DE PRODUCCIÓN &nbsp; 100% Nebbiolo. Nebbiolo es un tipo uva de baya de color (negro) considerada como una de las variedades más valiosas, aptas para el envejecimiento de vinos de la más alta calidad. El término “nebbiolo” al parecer proviene de la palabra “nebbia” (niebla en español), aunque es incierto si este es para definir el aspecto de la uva, oscura pero deslucida (nebulosa), o si se debe a la tardía maduración de la uva, que a menudo conduce a la cosecha durante las neblinas otoñales. Las uvas de las que se obtiene este excelente Barolo provienen exclusivamente de viñedos situados en altas colinas en Serralunga d’Alba, todos propiedad de la familia Lanzavecchia. El suelo es de margas calcáreas originales de la época de Mioceno Langhiense. </p><p id="">GRADUACIÓN ALCOHÓLICA &nbsp; 14% vol.</p>',
#    'notas-de-cata': 'De un color rojo granada, con un aroma etéreo, agradable e intenso, que nos recuerda las violetas, rosas secas, cerezas, vainilla, tabaco, trufas y pimienta. Su sabor es seco, con cuerpo, robusto, austero pero suave y armonioso. Es sin duda uno de los vinos italianos más importantes y reconocidos en el mundo gracias a sus características únicas y su elegancia innata.',
#    'categoria': 'Vinos y licores',
#    'cepa-principal': 'Nebbiolo',
#    'region': 'Piemonte',
#    'tipo': 'Tinto',
#    'item-id': '854',
#    'denominacion': 'DOCG',
#    'slug': 'barolo-2012-docg---media-botella-375ml',
#    'categories': '6660ca3823741b8f165309d1',
#    'imagen-del-producto': {'fileId': '665fd395fb56850f5f344a42',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/665fd395fb56850f5f344a42_BAROLO-2012-DOCG-MEDIA-BOTELLA-375ML-100-1.webp',
#     'alt': None},
#    'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False}},
#  {'id': '66615035437397bdd5e69b3f',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': '2025-03-12T23:21:57.135Z',
#   'lastUpdated': '2025-03-12T23:21:57.135Z',
#   'createdOn': '2024-06-06T05:59:17.371Z',
#   'isArchived': False,
#   'isDraft': False,
#   'fieldData': {'gr-ml': 'Mililitro a $143',
#    'ocasion': 'Cena entre amigos, Para todos los días, Todas las ocasiones',
#    'temperatura-de-servicio': '18-20 °C.',
#    'precio': '69000',
#    'maridaje-1': 'Carne',
#    'maridaje-2': 'Mexicano',
#    'pasillo': 'Vinos',
#    'bodega': 'Surrau',
#    'name': 'Cannonau "Surrau”',
#    'descripcion': '<p id="">ELABORACIÓN DEL VINO &nbsp; Vendimia manual, la fermentación toma lugar en tanques de acero inoxidable a temperatura controlada, en contacto con las cáscaras. Añejamiento por unos meses en tanques de cemento y acero.</p><p id="">VARIEDAD DE UVA Y ÁREA DE PRODUCCIÓN &nbsp; Cannonau 100%. Los viñedos se encuentran en colinas de 150 mts de altura, a pocos kilómetros del mar. Sus suelos principalmente compuestos por arena y granito y las plantaciones con orientación sur-este se benefician de los vientos marítimos que pasan por estas colinas.</p><p id="">GRADUACIÓN ALCOHÓLICA &nbsp; 14% vol.</p>',
#    'notas-de-cata': 'Color rojo rubí con reflejos granate. En la nariz se expresa con notas que recuerdan a los frutos negros como moras, ciruelas y cerezas. Taninos elegantes y sedosos. Persistente y expresivo en el paladar.',
#    'categoria': 'Vinos y licores',
#    'cepa-principal': 'Cannonau',
#    'region': 'Sardegna',
#    'tipo': 'Tinto',
#    'item-id': '857',
#    'denominacion': 'DOC',
#    'slug': 'surrau-cannonau-di-sardegna-doc',
#    'categories': '66635db36d9753905f695788',
#    'imagen-del-producto': {'fileId': '665fde3030ad3afaf60d216e',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/665fde3030ad3afaf60d216e_SURRAU-CANNONAU-DI-SARDEGNA-DOC-100-1.webp',
#     'alt': None},
#    'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'precio-descuento': '109000',
#    'productoreserva': False,
#    'descuento-off': False}},
#  {'id': '6661503579739759bbd7e0b5',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': None,
#   'lastUpdated': '2025-02-22T02:05:45.164Z',
#   'createdOn': '2024-06-06T05:59:17.363Z',
#   'isArchived': True,
#   'isDraft': True,
#   'fieldData': {'gr-ml': 'Mililitro a $163',
#    'ocasion': 'Cena entre amigos, Cena formal, Entre apasionados, Para todos los días, Todas las ocasiones',
#    'temperatura-de-servicio': '17-18 °C.',
#    'precio': '122000',
#    'maridaje-1': 'Todas las comidas',
#    'maridaje-2': 'Carne',
#    'pasillo': 'Vinos',
#    'bodega': 'Arrigoni',
#    'name': 'Chianti Poggio Al Vento',
#    'descripcion': '<p id="">ELABORACIÓN DEL VINO &nbsp; Vendimia manual, la fermentación toma lugar en tanques de acero inoxidable. La maduración se lleva a cabo en barricas de roble durante 8 meses mínimo y posteriormente afinamiento en botellas durante 4 meses.</p><p id="">VARIEDAD DE UVA Y ÁREA DE PRODUCCIÓN &nbsp; Sangiovese 100%. Los viñedos se encuentran en la zona del Chianti Colli Senesi, cerca de la ciudad de Siena, en la región de Toscana. Las colinas que rodean la ciudad de siena representan las mejores zonas para la elaboración de Chianti. Una de estas colinas es conocida como San Gimignano.</p><p id="">GRADUACIÓN ALCOHÓLICA &nbsp; 13,5% vol.</p>',
#    'notas-de-cata': 'Color rojo rubí brillante. En la nariz es perfumado y delicado, con notas que evocan a frutos del bosque, principalmente cerezas, algunas notas florales como violetas, también algunas notas especiadas como tabaco. En el paladar es fresco, de cuerpo medio, acidez elegante y taninos medios.',
#    'categoria': 'Vinos y licores',
#    'cepa-principal': 'Sangiovese',
#    'region': 'Toscana',
#    'tipo': 'Tinto',
#    'item-id': '858',
#    'denominacion': 'DOCG',
#    'slug': 'poggio-al-vento-chianti-colli-senesi-docg',
#    'categories': '6660ca3823741b8f165309d1',
#    'imagen-del-producto': {'fileId': '665fdf4069d1fb5886008b84',
#     'url': 'https://cdn.prod.website-files.com/664d95581633c04b8a3808d3/665fdf4069d1fb5886008b84_POGGIO-AL-VENTO-CHIANTI-COLLI-SENESI-DOCG-100-1.webp',
#     'alt': None},
#    'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': True}},
#  {'id': '666150356ada726de4353e0e',
#   'cmsLocaleId': '664d95581633c04b8a3808b5',
#   'lastPublished': None,
#   'lastUpdated': '2024-08-16T00:13:11.142Z',
#   'createdOn': '2024-06-06T05:59:17.360Z',
#   'isArchived': True,
#   'isDraft': False,
#   'fieldData': {'gr-ml': '264',
#    'ocasion': 'Cena formal, Entre apasionados, Ocasión especial, Todas las ocasiones, Vinos importantes',
#    'temperatura-de-servicio': '16-18 °C. Descorchar la botella media hora antes de servirlo.',
#    'precio': '198000',
#    'maridaje-1': 'Ideal para acompañar carnes rojas y de caza\\, como res y cordero. También es ideal con pastas y preparaciones estofadas. También es ideal para acompañar con charcutería y carnes curadas.',
#    'maridaje-2': 'Carne, Mexicano',
#    'pasillo': 'Vinos',
#    'bodega': 'Surrau',
#    'name': 'Cannonau Riserva "Sincaru"',
#    'descripcion': '<p>ELABORACIÓN DEL VINO   Vendimia manual, vinificación en tanques de acero a temperatura controlada. La fase de crianza en madera (roble eslavónico de tamaño medio) dura al menos 18 meses. Antes del embotellado se deja unos meses en pequeños tanques de hormigón, para luego trasladarlo a la botella donde permanecerá al menos seis meses.\\n\\nVARIEDAD DE UVA Y ÁREA DE PRODUCCIÓN   Cannonau 100%. Los viñedos están ubicados en el territorio de Arzachena, al norte de la isla. Para este vino, los viñedos se encuentran plantados en suelos de grava que le aporta balance y mineralidad. Sus suelos principalmente compuestos por arena y granito y las plantaciones con orientación sur-este se benefician de los vientos marítimos que pasan por estas colinas. Las vides que dan origen a este vino son vides de +10 años.\\n\\nGRADUACIÓN ALCOHÓLICA   14,5% vol.</p>',
#    'notas-de-cata': 'Color rojo rubí con reflejos granate. En la nariz tiene notas que recuerdan a las cerezas\\, fresas maduras\\, ciruelas y moras. Notas especiadas como pimienta y algún recuerdo de notas florales como rosas. En el paladar es elegante y persistente\\, taninos medios y suaves.',
#    'categoria': 'Vinos y licores',
#    'cepa-principal': 'Cannonau',
#    'region': 'Sardegna',
#    'tipo': 'Tinto',
#    'item-id': '855',
#    'denominacion': 'DOC',
#    'slug': 'sincaru-riserva-cannonau-di-sardegna-doc',
#    'categories': '6660ca3823741b8f165309d1',
#    'imagen-del-producto': {'fileId': '665fd6cd698fba26a4487f35',
#     'url': 'https://uploads-ssl.webflow.com/664d95581633c04b8a3808d3/665fd6cd698fba26a4487f35_SINCARU-RISERVA-CANNONAU-DI-SARDEGNA-DOC-100-1.jpg',
#     'alt': None},
#    'descuento': False,
#    'descuento-2x1': False,
#    'descuento-3x2': False,
#    'productoreserva': False,
#    'descuento-off': False}}]

# %%
# Out:
# ✅ Fetched 100 items at offset 0
# ✅ Fetched 100 items at offset 100
# ✅ Fetched 100 items at offset 200
# ✅ Fetched 100 items at offset 300
# ✅ Fetched 20 items at offset 400

# %%
df
# Out:
#                            id             lastPublished  \
# 0    6823fa2dd9f312dbdbb2de73  2025-05-14T02:04:29.094Z
# 1    6823f83f37e7dd18f6e1d4ed  2025-05-14T12:37:08.834Z
# 2    6823f71280a8d9de4f1a43f8  2025-05-14T01:58:12.446Z
# 3    6823f68302f24dd9e4b9df4f  2025-05-14T01:59:01.100Z
# 4    67e03ce522349689dfa5d528  2025-05-05T23:32:45.915Z
# ..                        ...                       ...
# 415  666150354f742af9a75e85b3  2025-03-12T23:27:56.606Z
# 416  66615035a7cc81d396c88077                      None
# 417  66615035437397bdd5e69b3f  2025-03-12T23:21:57.135Z
# 418  6661503579739759bbd7e0b5                      None
# 419  666150356ada726de4353e0e                      None
#
#                   lastUpdated  isArchived  isDraft                   gr-ml  \
# 0    2025-05-14T02:04:29.094Z       False    False   Mililitro por $245,71
# 1    2025-05-14T12:37:08.834Z       False    False   Mililitro por $245,71
# 2    2025-05-14T01:58:12.446Z       False    False  Mililitro por $302,85
# 3    2025-05-14T01:59:01.100Z       False    False          $327,14 por ml
# 4    2025-04-29T15:40:48.836Z       False    False                    None
# ..                        ...         ...      ...                     ...
# 415  2025-03-12T23:27:56.606Z       False    False        Mililitro a $205
# 416  2025-02-07T04:30:44.636Z        True     True        Mililitro a $435
# 417  2025-03-12T23:21:57.135Z       False    False        Mililitro a $143
# 418  2025-02-22T02:05:45.164Z        True     True        Mililitro a $163
# 419  2024-08-16T00:13:11.142Z        True    False                     264
#
#                                                ocasion  precio  \
# 0                                                 None  137600
# 1                                                 None  137600
# 2                                                 None  169600
# 3                                                 None  183200
# 4                                                 None   46000
# ..                                                 ...     ...
# 415  Cena entre amigos, Cena formal, Entre apasiona...  154000
# 416  Cena formal, Entre apasionados, Ocasión especi...  163000
# 417  Cena entre amigos, Para todos los días, Todas ...   69000
# 418  Cena entre amigos, Cena formal, Entre apasiona...  122000
# 419  Cena formal, Entre apasionados, Ocasión especi...  198000
#
#                                             maridaje-1       maridaje-2  ...  \
# 0                                                 None             None  ...
# 1                                                 None             None  ...
# 2                                                 None             None  ...
# 3                                                 None             None  ...
# 4                                                 None             None  ...
# ..                                                 ...              ...  ...
# 415                                      Pasta y Pizza            Sushi  ...
# 416                                  Todas las comidas            Carne  ...
# 417                                              Carne         Mexicano  ...
# 418                                  Todas las comidas            Carne  ...
# 419  Ideal para acompañar carnes rojas y de caza\, ...  Carne, Mexicano  ...
#
#                            name  \
# 0               Vermouth Blanco
# 1                 Vermouth Rojo
# 2                   Gin Pigskin
# 3                Boigin Saffron
# 4              Mascarpone 500gr
# ..                          ...
# 415          Cannonau "Sincaru"
# 416                Barolo 375ml
# 417           Cannonau "Surrau”
# 418     Chianti Poggio Al Vento
# 419  Cannonau Riserva "Sincaru"
#
#                                            descripcion  \
# 0    <p>Esta inspirado en las recetas clásicas de p...
# 1    <p>Se elabora a partir de Vernaccia di Oristan...
# 2    <p>Contiene botánicos locales como enebro sard...
# 3    <p>Utiliza azafrán sardo de alta calidad, lo q...
# 4    <p>El mascarpone, típicamente lombardo,se elab...
# ..                                                 ...
# 415  <p id="">ELABORACIÓN DEL VINO &nbsp; Vendimia ...
# 416  <p id="">ELABORACIÓN DEL VINO &nbsp; La uva es...
# 417  <p id="">ELABORACIÓN DEL VINO &nbsp; Vendimia ...
# 418  <p id="">ELABORACIÓN DEL VINO &nbsp; Vendimia ...
# 419  <p>ELABORACIÓN DEL VINO   Vendimia manual, vin...
#
#                                          notas-de-cata   tipo  \
# 0                                                 None   None
# 1                                                 None   None
# 2                                                 None   None
# 3                                                 None   None
# 4                                                 None   None
# ..                                                 ...    ...
# 415  Color rojo rubí con reflejos violáceos. En la ...  Tinto
# 416  De un color rojo granada, con un aroma etéreo,...  Tinto
# 417  Color rojo rubí con reflejos granate. En la na...  Tinto
# 418  Color rojo rubí brillante. En la nariz es perf...  Tinto
# 419  Color rojo rubí con reflejos granate. En la na...  Tinto
#
#                                           slug descuento descuento-2x1  \
# 0                              vermouth-blanco     False         False
# 1                                vermouth-rojo     False         False
# 2                                  gin-pigskin     False         False
# 3                               boigin-saffron     False         False
# 4                             mascarpone-500gr     False         False
# ..                                         ...       ...           ...
# 415           sincaru-cannonau-di-sardegna-doc     False         False
# 416     barolo-2012-docg---media-botella-375ml     False         False
# 417            surrau-cannonau-di-sardegna-doc     False         False
# 418  poggio-al-vento-chianti-colli-senesi-docg     False         False
# 419   sincaru-riserva-cannonau-di-sardegna-doc     False         False
#
#      descuento-3x2  productoreserva  descuento-off
# 0            False            False          False
# 1            False            False          False
# 2            False            False          False
# 3            False            False          False
# 4            False            False          False
# ..             ...              ...            ...
# 415          False            False          False
# 416          False            False          False
# 417          False            False          False
# 418          False            False           True
# 419          False            False          False
#
# [420 rows x 22 columns]
